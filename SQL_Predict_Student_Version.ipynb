# %% [markdown]
# # SQL 4 Data Science: Predict Project
# ## Bhejane Online Trading Store
#
# ### Student Starter Notebook
#
# © Explore Data Science Academy
#
# ### Honour Code
#
# I {**Nompumelelo**, **Ncube **}, confirm - by submitting this document - that the solutions in this notebook are a result of my own work and that I abide by the EDSA honour code (https://drive.google.com/file/d/1QDCjGZJ8-FmJE3bZdIQNwnJyQKPhHZBn/view?usp=sharing).
#
# Non-compliance with the honour code constitutes a material breach of contract.

# %% [markdown]
# <a id='Context'></a>
# ### 1. Context
#
# The Bhejane trading store is an online retailer specialising in Covid essential items. The store has recently been struggling with the management of its database-related inventory system. Luckily for them, you've been hired as a consultant to fix the problem.
#
# Its time to flex your Ninja SQL skills!
#
# **Your mission, should you choose to accept it:**
#
# You will receive a denormalised database consisting of two tables. Your task is to transform the database such that is in third normal form (3NF). To ensure that a consistent normalisation process is followed by each student, we have attached an Entity Relationship Diagram (ERD) which is a guideline on what tables need to be produced. Once you have normalised the database, you will be required to complete an MCQ test found under the 'Predict' tab of Athena.
#
# Though the normalisation process, you will be guided into acknowledging client (Bhenjane Trading) use-cases for the database, and dealing with data anomalies in SQL.

# %% [markdown]
# ![Bhejane company logo](https://raw.githubusercontent.com/Explore-AI/Pictures/master/SQL4DS/SQL_Predict/Bhejane.png)

# %% [markdown]
# <div align="center" >
#     Bhejane, or the Black Rhino. Image by <a href="https://commons.wikimedia.org/wiki/File:Black_Rhino_(Diceros_bicornis)_browsing_..._(46584052962).jpg">Wikimedia Commons</a>
# </div>

# %% [markdown]
# <a id='Imports'></a>
# ### 2. Imports
# Please use the below command to install sql_magic, this is the package that will assist you with SQL syntax hightlighting.
# * pip install sql_magic
#
# Remember to start each new cell with " %%read_sql "

# %%
# %load_ext sql

# %%
# %%sql
#
# sqlite:///bhejane.db

# %% [markdown]
# <a id='Data_description'></a>
# ### 3. Data description
#
# The original database consist of 2 tables.
# * Product Table
# * Transaction Table
#
# The `Product` table consists of the stock of all inventory that Bhejane has on hand currently, or has had on hand historically. Items which are in this table are able to be purchased, and a record of all sales (transactions) in 2020 is notorised in the `Transactions` table. To link the tables - the `barcode` can be used. Any item in the `Transactions` table, must therefore appear in the `Products` table.

# %%
# DO NOT EDIT THIS CELL
import pandas as pd
data_description = pd.read_excel('Data Description.xlsx')
data_description
# Out:
#       Table Name         Column Name  \
# 0       Products               Width
# 1       Products              Length
# 2       Products              Height
# 3       Products             Barcode
# 4       Products            Quantity
# 5       Products               Brand
# 6       Products      NavigationPath
# 7       Products              Colour
# 8       Products        StockCountry
# 9       Products  ProductDescription
# 10      Products            PackType
# 11      Products        Volume_litre
# 12      Products            Warranty
# 13      Products           Weight_kg
# 14      Products     ItemDescription
# 15      Products               Price
# 16  Transactions              CartID
# 17  Transactions             Barcode
# 18  Transactions               Total
# 19  Transactions            UserName
# 20  Transactions         InvoiceDate
#
#                                           Desciption
# 0                 Width of the product once assembled
# 1                Length of the product once assembled
# 2                Height of the product once assembled
# 3                      The unique product identifier
# 4                            Number of goods in stock
# 5      Product brand name relating to product company
# 6                 Navigation path to specific product
# 7                 Name default colour for the product
# 8             Country where the stock was bought from
# 9                            Descriptive product name
# 10           The way in which the product is packaged
# 11              The quantity of liquid based products
# 12                              Product warranty type
# 13                              Weight of the product
# 14            Description of contents of the package
# 15                   The cost of the product in Rands
# 16  Identifies an individual basket from a user pu...
# 17               Barcode for item that user purchased
# 18                      Total value of a transaction
# 19                  Name of customer purchasing stock
# 20               Date on which the product was bought

# %% [markdown]
# <a id='Setting_up'></a>
# ### 4. Setting up the database

# %%
import sqlite3

# Now you can use sqlite3
conn = sqlite3.connect('bhejane.db')
cursor = conn.cursor()

# %% [markdown]
# #### Creating both Products and Transaction Tables

# %%
# %%sql
# --DO NOT EDIT THIS CELL
# DROP TABLE IF EXISTS "Products";
# DROP TABLE IF EXISTS "Transactions";
#
# CREATE TABLE "Products" (
#     "Width"   REAL,
#     "Length"  REAL,
#     "Height"  REAL,
#     "Barcode" VARCHAR(150),
#     "Quantity" REAL,
#     "Brand" VARCHAR(150),
#     "NavigationPath" VARCHAR(150),
#     "Colour" VARCHAR(150),
#     "StockCountry" VARCHAR(150),
#     "ProductDescription" VARCHAR(150),
#     "PackType" VARCHAR(150),
#     "Volume_litre" REAL,
#     "Warranty" VARCHAR(150),
#     "Weight_kg" REAL,
#     "ItemDescription" VARCHAR(150),
#     "Price" REAL
# );
#
#
# CREATE TABLE "Transactions" (
#     "CartID" INTEGER,
#     "Barcode" VARCHAR(150),
#     "Total" REAL,
#     "UserName" VARCHAR(150),
#     "InvoiceDate" DATETIME
# );
# Out:
#  * sqlite:///bhejane.db
# Done.
# Done.
# Done.
# Done.
# []

# %% [markdown]
# #### Load Data into Product and Transaction tables
#
# Although we have not yet covered python in the sprint at EXPLORE - you have additional resources at your disposal, one of which happens to be a data engineering expert, and she has created a brief script for you which can be used to extract the data from the csv files, and load it into a sqlite database.
#
# This will be included in your submission, so that the end-to-end processing of the data is visible, and repeatable for any additional consultants who may be brought on board at a later stage.

# %%
import pandas as pd


# Establish a connection to the SQLite database
conn = sqlite3.connect('bhejane.db')

# Load data from CSV into a DataFrame
products_df = pd.read_csv('bhejane_covid_essentials_Products.csv')

# Insert data into the Products table
products_df.to_sql('Products', conn, if_exists='append', index=False)

# Load data from another CSV into a DataFrame
transactions_df = pd.read_csv('bhejane_covid_essentials_Transactions.csv')

# Insert data into the Transactions table
transactions_df.to_sql('Transactions', conn, if_exists='append', index=False)

# Close the database connection
conn.close()

# %% [markdown]
# <a id='ERD'></a>
# ### 5. Denormalized Database Tables
#
# <br>
#
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/SQL4DS/SQL_Predict/Denormalized_Tables.png" alt="Denormalized Tables" border="0">

# %% [markdown]
# #### 5.1 Explore the Denormalized Tables
# Familiarize yourself with the data given in the two tables by writing your own SQL queries to explore properties of the dataset.i.e Look for data inconsistencies, anormalies, redundancies etc to guide your normalization process.
#
# This section will not be graded - think of it as your own scratch pad.

# %%
# %%sql
# -- #Use this section to explore the database by writing your own queries
# SELECT * FROM Products
# LIMIT 2;
# Out:
#  * sqlite:///bhejane.db
# Done.
# [(None, None, None, '300507946', 493.0, 'Hikvision', 'Computers & Tablets / Smart Home & Connected Living / Home Security / Security Cameras', None, None, 'Hikvision 1080P 2MP Turbo HD IR Bullet Camera', None, 0.0, 'Limited (6 months)', None, '1 x Hikvision 1080P Bullet camera', 399.0),
#  (None, None, None, '300507946', 493.0, 'Hikvision', 'Computers & Tablets / Smart Home & Connected Living / Home Security / Security Cameras', None, None, 'Hikvision 1080P 2MP Turbo HD IR Bullet Camera', None, 0.0, 'Limited (6 months)', None, 'Manual', 399.0)]

# %% [markdown]
# ### 6. Normalize the given Database tables to the 1st Normal Form (1NF)
#
# Given the below below target ERD create new tables such the the database conforms to the 1st Normal Form
#
# ![1st Normal Form](https://raw.githubusercontent.com/Explore-AI/Pictures/master/SQL4DS/SQL_Predict/1stNF.png)
#
#
# It is suggested that you create all your tables before attempting to populate them with data, this will help reduce errors that might creep up due to logical dependencies.

# %% [markdown]
# #### 6.1 Create the tables required for the 1st Normal Form
# Use the above ERD sketch to create the required tables. Please label your tables as they appear in the ERD sketch

# %%
# %%sql
# --#Create tables required for 1NF
# DROP TABLE IF EXISTS "Products_1NF";
# DROP TABLE IF EXISTS "Transactions_1NF";
#
# CREATE TABLE "Products_1NF"(
#     "Barcode" VARCHAR(150),
#     "NavigationPath" VARCHAR(150),
#     "ItemDescription" VARCHAR(150),
#     "Colour" VARCHAR(150),
#     "ProductDescription" VARCHAR(150) NOT NULL,
#     "Brand" VARCHAR(150),
#     "Price" REAL NOT NULL,
#     "Quantity" INTEGER NOT NULL,
#     "PackType" VARCHAR(150),
#     "Warranty" VARCHAR(150),
#     "StockCountry" VARCHAR(150),
#     "Weight_kg" REAL,
#     "Volume_litre" REAL,
#     "Length" REAL,
#     "Width" REAL,
#     "Height" REAL,
#     PRIMARY KEY("Barcode","NavigationPath","ItemDescription")
# );
#
# CREATE TABLE "Transactions_1NF" (
#     "CartID" INTEGER NOT NULL,
#     "Barcode" VARCHAR(150) NOT NULL,
#     "UserName" VARCHAR(150) NOT NULL,
#     "InvoiceDate" DATETIME NOT NULL,
#     "Total" REAL NOT NULL,
#     FOREIGN KEY ("Barcode") REFERENCES "Products_1NF" ("Barcode"),
#     PRIMARY KEY("CartID", "Barcode", "UserName")
# );
# Out:
#  * sqlite:///bhejane.db
# Done.
# Done.
# Done.
# Done.
# []

# %% [markdown]
# #### 6.2 Populate the tables you have create in the above section.
#
# Populate the tables such that the database conforms to the 1st Normal Form

# %%
# %%sql
# --#Populate the 1NF tables
# DELETE FROM "Products_1NF";
# DELETE FROM "Transactions_1NF";
#
# INSERT INTO "Products_1NF" ("Barcode","NavigationPath","ItemDescription","Colour","ProductDescription","Brand",
#                             "Price","Quantity","PackType","Warranty","StockCountry","Weight_kg",
#                             "Volume_litre","Length","Width","Height")
# SELECT DISTINCT
#      Barcode
#     ,NavigationPath
#     ,ItemDescription
#     ,Colour
#     ,ProductDescription
#     ,Brand
#     ,Price
#     ,Quantity
#     ,PackType
#     ,Warranty
#     ,StockCountry
#     ,Weight_kg
#     ,Volume_litre
#     ,Length
#     ,Width
#     ,Height
# FROM
#     Products;
#
# INSERT INTO "Transactions_1NF"("CartID","Barcode","UserName","InvoiceDate","Total")
# SELECT DISTINCT
#     CartID
#     ,Barcode
#     ,UserName
#     ,InvoiceDate
#     ,Total
# FROM
#     Transactions;
# Out:
#  * sqlite:///bhejane.db
# Done.
# 0 rows affected.
# 1162 rows affected.
# 278 rows affected.
# []

# %% [markdown]
# ###  7. Convert the database into its 2nd Normal Form (2NF).
#
# Please label your tables as they appear in the ERD sketch.
#
# #### 7.1 Entity Relationship Diagram
#
# ![2nd Normal Form](https://raw.githubusercontent.com/Explore-AI/Pictures/master/SQL4DS/SQL_Predict/2ndNF.png)
#
# #### 7.2 2NF Requirements
# To transition from 1NF to 2NF, we need all columns in all tables to not have a partial dependancy on the PK of the table. This means that any tables which have a composite key e.g. `PRIMARY KEY("Barcode","NavigationPath","ItemDescription")` cannot have columns in the table which are dependant on only `Barcode`, `NavigationPath`, or `ItemDescription`.
#
# In moving to 2NF we will seperate out each of these as a primary key (for their own respective tables), and any columns dependant on one of these columns but not the others, will go into that table. The only columns remaining in the tables will be fully functionally dependant on the primary key of the table. For example,
#
# Thereby, we remove the partial dependancy, and will be in 2NF. We are instructed to create a unique identifier for the `Transactions_2NF`.
#
# **Second normal form notes**
#
# <br>$\bullet$ Notice that `Total` is only dependant on `CartID` and not on `<CartID,barcode>`. This is a partial dependancy
# <br>$\bullet$ Second normal form required no *partial functional dependancy* on the key.
# <br>$\bullet$ This can be achieved in 2 ways: create a unique identifier per row (so that there is a simple primary key), or break the table up into only the columns which are fully dependant on the composite key.
# <br>$\bullet$ We are going to opt for the easier solution, and create a unique simple primary key on the `Transactions_1NF`. We can create a unique primary key by concatenating `CartID||barcode`
# <br>$\bullet$ NB - this approach does make it more challenging to get into 3NF! Which would be a good argument to opt for the latter approach.

# %% [markdown]
# #### 7.3 Data Anomalies
#
# You may stumble into an error when you insert the data which violates this constraint. You query this with the data owner, and you are told that there are three transactions in the database which were errors. You are informed that *all transactions in the database correspond to products are in the database*.
#
# These entries were captured incorrectly, and must be removed. How will you deal with this?

# %%
# %%sql
# SELECT COUNT(DISTINCT barcode) FROM Transactions_1NF WHERE barcode NOT IN (SELECT barcode FROM products_1NF);
# Out:
#  * sqlite:///bhejane.db
# Done.
# [(2,)]

# %% [markdown]
# ### <font color='turquoise'>Action: remove the affected entries with a `delete` query </font>

# %%
# %%sql
# delete from  Transactions_1NF
# WHERE CartID < 0;
# Out:
#  * sqlite:///bhejane.db
# 0 rows affected.
# []

# %%
# %%sql
# -- Should show no entries!
# select count(distinct barcode) from Transactions_1NF where barcode not in (select barcode from products_1NF)
# Out:
#  * sqlite:///bhejane.db
# Done.
# [(2,)]

# %% [markdown]
# #### 7.4 FK Requirements
#
# _Note: sqlite does not always enforce foreign key constraints (and it is even more inconsistent with magic commands to enforce FK constraints!), so it is critical that you understand the purpose of the foreign key constraint and therefore are able to enforce the FK constraint yourself!_
#
# To enforce data integrity, and to ensure that strange things cannot happen - we will have a FK constraint. A foreign key forces all values of the FK, to be limited to only the values which exist as entries in the PK column of the table for which the aforementioned table is a foreign key to. For example, we cannot sell a product (in our Transactions table) which we do not have in our Products table.
#
# You will need to work around this by removing the erroneous data from the tables before continuing, since this would violate the FK constraint between the Transactions_2NF and Products_2NF table otherwise.
#
# _Hint: Identify the observations in the Transactions_1NF table, and remove them from there._
#
# #### 7.5 Client Use-Case Requirements
#
# The data owner has advised that there were several instances of incorrect data capturing. Whenever data was partially captured, it was redone, but the partially-complete entries have not been removed from the database.
#
# For all tables which are going to be used, consider the table utility relative to the Products (Products_2NF) table. You are tasked with removing 'useless' entries as you take the data from 1NF to 2NF. For the sake of ease-of-use for the client, we will removing all rows in the 2NF tables `PackageContents_2NF` and `Colours_2NF` which have an empty value for the attributes that the client will use them for - these are the `ItemDescription` and `Colour` columns, respectively.
#
# _Hint: Make inserts into the other 2NF (`PackageContents_2NF` and `Colours_2NF`) tables using a `where` clause to remove instances of the value being an empty string, or a `null` value. This will need to be considered for the `ItemDescription` and for the `Colour` when data is inserted into the corresponding tables above (i.e. only insert data into the `PackageContents_2NF` which has a value for the `ItemDescription`, and only insert data into the `Colours_2NF` table which has a value for `Colour`_

# %% [markdown]
# ### <font color='turquoise'>Action: Investigate these anomalies for the tables mentioned </font>

# %%
# %%sql
#
# SELECT DISTINCT
#     ItemDescription,
#     PackType,
#     Warranty
# FROM
#     Products
# WHERE ItemDescription = '';
# Out:
#  * sqlite:///bhejane.db
# Done.
# []

# %% [markdown]
# ### Let's do it! Construct the database above in second normal form

# %%
# %%sql
# --#Create tables required for 2NF
#
# DROP TABLE IF EXISTS "Products_2NF";
# DROP TABLE IF EXISTS "Transactions_2NF";
# DROP TABLE IF EXISTS "Navigation_2NF";
# DROP TABLE IF EXISTS "PackageContents_2NF";
# DROP TABLE IF EXISTS "Colours_2NF";
#
# CREATE TABLE Products_2NF(
#     "RegistryID" INTEGER NOT NULL,
#     "Barcode" VARCHAR(150) NOT NULL,
#     "ProductDescription" VARCHAR(150) NOT NULL,
#     "Brand" VARCHAR(150),
#     "Price" REAL NOT NULL,
#     "Quantity" INTEGER NOT NULL,
#     "StockCountry" VARCHAR(150),
#     "Weight_kg" REAL,
#     "Volume_litre" REAL,
#     "Length" REAL,
#     "Width" REAL,
#     "Height" REAL,
#     "PathID" INTEGER,
#     "ItemID" INTEGER,
#     "ColourID" INTEGER,
#     PRIMARY KEY(RegistryID AUTOINCREMENT),
#     CONSTRAINT fk_nav FOREIGN KEY('PathID') REFERENCES Navigation_2NF ('PathID'),
#     CONSTRAINT fk_pack FOREIGN KEY('ItemID') REFERENCES PackageContents_2NF ('ItemID'),
#     CONSTRAINT fk_col FOREIGN KEY('ColourID') REFERENCES Colours_2NF ('ColourID')
# );
#
# CREATE TABLE "Transactions_2NF" (
#     "CartID||Barcode||UserName" VARCHAR(150) NOT NULL,
#     "CartID" INTEGER NOT NULL,
#     "Barcode" VARCHAR(150) NOT NULL,
#     "UserName" VARCHAR(150) NOT NULL,
#     "InvoiceDate" DATETIME NOT NULL,
#     "Total" REAL NOT NULL,
#     PRIMARY KEY("CartID||Barcode||UserName")
#     CONSTRAINT fk_trans FOREIGN KEY('Barcode') REFERENCES Products_2NF ('Barcode')
# );
#
#
# CREATE TABLE "Navigation_2NF"(
#     "PathID" INTEGER NOT NULL,
#     "NavigationPath" VARCHAR(150),
#     PRIMARY KEY("PathID" AUTOINCREMENT)
# );
#
# CREATE TABLE "Colours_2NF"(
#     "ColourID" INTEGER NOT NULL,
#     "Colour" VARCHAR(150),
#     PRIMARY KEY("ColourID" AUTOINCREMENT)
# );
#
# CREATE TABLE "PackageContents_2NF"(
#     "ItemID" INTEGER NOT NULL,
#     "ItemDescription" VARCHAR(150),
#     "PackType" VARCHAR(150),
#     "Warranty" VARCHAR(150),
#     PRIMARY KEY("ItemID" AUTOINCREMENT)
# );
# Out:
#  * sqlite:///bhejane.db
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# []

# %% [markdown]
# ### Let's do it! _Populate_ the database above in second normal form
#
# Firstly, let's consider the entries which are `null` and `= ''`. And we will only insert the relevant entries.

# %%
# %%sql
# -- #Populate the tables so that they conform to 2NF
#
# DELETE FROM "Products_2NF";
# DELETE FROM "Transactions_2NF";
# DELETE FROM "Navigation_2NF";
# DELETE FROM "PackageContents_2NF";
# DELETE FROM "Colours_2NF";
#
#
# INSERT INTO "Navigation_2NF"("NavigationPath")
# SELECT DISTINCT
#     NavigationPath
# FROM
#     Products_1NF;
#
# INSERT INTO "PackageContents_2NF"("ItemDescription","PackType","Warranty")
# SELECT DISTINCT
#     ItemDescription,
#     PackType,
#     Warranty
# FROM
#     Products_1NF
# WHERE ItemDescription <> ''
#         ;
#
# INSERT INTO "Colours_2NF"("Colour")
# SELECT DISTINCT
#     Colour
# FROM
#     Products_1NF
# WHERE Colour <> ''
#         ;
# Out:
#  * sqlite:///bhejane.db
# Done.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 396 rows affected.
# 600 rows affected.
# 17 rows affected.
# []

# %% [markdown]
# A more complicated scenario below as we insert into `Products_2NF`. We will insert from the Products_1NF table. We can use LEFT JOIN, because the data in each of these tables that `Products_1NF` has a FK to, originally came from `Products_1NF`, so we are gauranteed to get matches back. Normally however, what you would get from the FK restriction is the requirement to use _parent-table_ `LEFT JOIN` _child-table_.

# %%
# %%sql
#
# INSERT INTO "Products_2NF" ("PathID","ItemID","ColourID","Barcode","ProductDescription","Brand","Price",
#                             "Quantity","StockCountry","Weight_kg","Volume_litre",
#                             "Length","Width","Height")
# SELECT
#     PathID,
#     ItemID,
#     ColourID,
#     Products_1NF.Barcode,
#     ProductDescription,
#     Brand,
#     Price,
#     Quantity,
#     StockCountry,
#     Weight_kg,
#     Volume_litre,
#     Length,
#     Width,
#     Height
# FROM
#     Products_1NF
# LEFT JOIN Navigation_2NF ON Products_1NF.NavigationPath = Navigation_2NF.NavigationPath
# LEFT JOIN PackageContents_2NF ON Products_1NF.ItemDescription = PackageContents_2NF.ItemDescription
# LEFT JOIN Colours_2NF ON Products_1NF.Colour = Colours_2NF.Colour
# Out:
#  * sqlite:///bhejane.db
# 1214 rows affected.
# []

# %% [markdown]
# Last but not least, we insert into the `Transactions_2NF`table. Recall that we created a new PK in this table, and pay attention to how we are inserting values into the table.

# %%
# %%sql
#
# INSERT INTO "Transactions_2NF"("CartID||Barcode||UserName","CartID","Barcode","UserName","InvoiceDate","Total")
# SELECT DISTINCT
#     CartID||Transactions_1NF.Barcode||UserName
#     ,CartID
#     ,Transactions_1NF.Barcode
#     ,UserName
#     ,InvoiceDate
#     ,Total
# FROM
#     Transactions_1NF
# LEFT JOIN Products_2NF ON Transactions_1NF.Barcode = Products_2NF.Barcode ;
# Out:
#  * sqlite:///bhejane.db
# 278 rows affected.
# []

# %% [markdown]
# <a id='Target_ERD'></a>
# ### 8. Convert the table into its 3rd Normal Form (3NF)
#
# Please label your tables as they appear in the ERD sketch. In the same fashion as done in 2NF, note which tables need to have data inserted `where column <> '' and column is not null`.
#
# <br>
#
# ![3rd Normal Form](https://raw.githubusercontent.com/Explore-AI/Pictures/master/SQL4DS/SQL_Predict/3rdNF.png)

# %%
# %%sql
#
# --#Create tables required for 2NF
# DROP TABLE IF EXISTS "Transactions_3NF";
# DROP TABLE IF EXISTS "Carts_3NF";
# DROP TABLE IF EXISTS "Products_3NF";
# DROP TABLE IF EXISTS "Users_3NF";
# DROP TABLE IF EXISTS "Navigation_3NF";
# DROP TABLE IF EXISTS "PackageContents_3NF";
# DROP TABLE IF EXISTS "Colours_3NF";
# DROP TABLE IF EXISTS "Brands_3NF";
# DROP TABLE IF EXISTS "Locations_3NF";
#
# CREATE TABLE "Products_3NF" (
#     "RegistryID" INTEGER NOT NULL,
#     "Barcode" VARCHAR(150) NOT NULL,
#     "ProductDescription" VARCHAR(150) NOT NULL,
#     "Price" REAL NOT NULL,
#     "Quantity" INTEGER NOT NULL,
#     "Weight_kg" REAL,
#     "Volume_litre" REAL,
#     "Length" REAL,
#     "Width" REAL,
#     "Height" REAL,
#     "PathID" INTEGER,
#     "ItemID" INTEGER,
#     "ColourID" INTEGER,
#     "BrandID" INTEGER,
#     "LocationID" INTEGER,
#     PRIMARY KEY("RegistryID" AUTOINCREMENT),
#     FOREIGN KEY("PathID") REFERENCES "Navigation_3NF" ("PathID"),
#     FOREIGN KEY("ItemID") REFERENCES "PackageContents_3NF" ("ItemID"),
#     FOREIGN KEY("ColourID") REFERENCES "Colours_3NF" ("ColourID") ,
#     FOREIGN KEY ("BrandID") REFERENCES "Brands_3NF" ("BrandID"),
#     FOREIGN KEY ("LocationID") REFERENCES "Locations_3NF" ("LocationID")
# );
#
#
# CREATE TABLE "Carts_3NF" (
#     "CartID" INTEGER NOT NULL,
#     "InvoiceDate" DATETIME NOT NULL,
#     "Total" REAL NOT NULL,
#     PRIMARY KEY ("CartID")
# );
#
#
# CREATE TABLE "Users_3NF"(
#     "UserID" INTEGER NOT NULL,
#     UserName VARCHAR(50) NOT NULL,
#     PRIMARY KEY("UserID" AUTOINCREMENT)
# );
# Out:
#  * sqlite:///bhejane.db
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# []

# %% [markdown]
# ### <font color='turquoise'>Action: proceed with the construction of the remaining tables mentioned </font>

# %%
# %%sql
#
# CREATE TABLE "Transactions_3NF" (
#     "CartID" VARCHAR(150) NOT NULL,
#     "Barcode" VARCHAR(150) NOT NULL,
#     "Username" VARCHAR(150) NOT NULL,
#     "UserID" INTEGER NOT NULL,
#     PRIMARY KEY ("CartID", "Barcode", "Username"),
#     FOREIGN KEY ("UserID") REFERENCES "Users_3NF" ("UserID"),
#     FOREIGN KEY ("Barcode") REFERENCES "Products_3NF" ("Barcode")
# );
# CREATE TABLE "Navigation_3NF" (
#     "PathID" INTEGER NOT NULL,
#     "NavigationPath" VARCHAR(150),
#     PRIMARY KEY ("PathID")
# );
#
# CREATE TABLE "PackageContents_3NF" (
#     "ItemID" INTEGER NOT NULL,
#     "ItemDescription" VARCHAR(150) NOT NULL,
#     "PackType" VARCHAR(150) NOT NULL,
#     "Warranty" VARCHAR(150) NOT NULL,
#     PRIMARY KEY ("ItemID")
# );
#
# CREATE TABLE "Colours_3NF" (
#     "ColourID" INTEGER NOT NULL,
#     "Colour" VARCHAR(150) NOT NULL,
#     PRIMARY KEY ("ColourID")
# );
#
# CREATE TABLE "Brands_3NF" (
#     "BrandID" INTEGER NOT NULL,
#     "Brand" VARCHAR(150) NOT NULL,
#     PRIMARY KEY ("BrandID")
# );
#
# CREATE TABLE "Locations_3NF" (
#     "LocationID" INTEGER NOT NULL,
#     "StockCountry" VARCHAR(150) NOT NULL,
#     PRIMARY KEY ("LocationID")
# );
# Out:
#  * sqlite:///bhejane.db
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# []

# %%
# %%sql
#
# --# Populate the tables to that they conform to the 3rd Normal Form
# DELETE FROM "Products_3NF";
# DELETE FROM "Transactions_3NF";
# DELETE FROM "Carts_3NF";
# DELETE FROM "Users_3NF";
# DELETE FROM "Navigation_3NF";
# DELETE FROM "PackageContents_3NF";
# DELETE FROM "Colours_3NF";
# DELETE FROM "Brands_3NF";
# DELETE FROM "Locations_3NF";
#
# INSERT INTO "Users_3NF" ("UserName")
# SELECT DISTINCT UserName FROM Transactions_2NF;
# Out:
#  * sqlite:///bhejane.db
# Done.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 160 rows affected.
# []

# %% [markdown]
# ### <font color='turquoise'>Action: proceed with the insertion into `Carts_3NF`.   </font>
#
# Take note that there are duplicate values coming from `Transactions_2NF` - retain the `distinct` combinations of `CartID`,`InvoiceDate`,`Total` only.

# %%
# %%sql
# INSERT INTO Carts_3NF (CartID, InvoiceDate, Total)
# SELECT DISTINCT CartID, InvoiceDate, Total
# FROM Transactions_2NF;
# Out:
#  * sqlite:///bhejane.db
# 192 rows affected.
# []

# %% [markdown]
# ### <font color='turquoise'>Action: proceed with the insertion into the tables below. </font>
#
# Similarly to the table above, mind the occurances of duplicate entries. These can be avoided by using `SELECT distinct` to avoid inserting redundant rows.

# %%
# %%sql
#
# INSERT INTO Locations_3NF (StockCountry)
# SELECT COALESCE("StockCountry", 'Unknown')
# FROM Products_2NF;
#
# INSERT INTO Brands_3NF (Brand)
# SELECT COALESCE("Brand", 'Unknown')
# FROM Products_2NF;
#
# INSERT INTO "Colours_3NF" ("Colour")
# SELECT DISTINCT "Colour"
# FROM Products_2NF;
#
# INSERT INTO "PackageContents_3NF" ("ItemDescription", "PackType", "Warranty")
# SELECT DISTINCT "ItemDescription", "PackType", "Warranty"
# FROM Products_2NF;
#
# INSERT INTO "Navigation_3NF" ("NavigationPath")
# SELECT DISTINCT "NavigationPath"
# FROM Products_2NF;
# Out:
#  * sqlite:///bhejane.db
# 1214 rows affected.
# 1214 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# []

# %% [markdown]
# ### <font color='turquoise'>Action: proceed with the insertion into `Products_3NF`. </font>
# Take note of the joins required for additional data contained in other tables.

# %%
# %%sql
# INSERT INTO "Products_3NF" ("PathID", "ItemID", "ColourID", "BrandID", "LocationID",
#                             "Barcode", "ProductDescription", "Price",
#                             "Quantity", "Weight_kg", "Volume_litre",
#                             "Length", "Width", "Height")
# SELECT
#     N.PathID,
#     PC.ItemID,
#     C.ColourID,
#     B.BrandID,
#     L.LocationID,
#     P.Barcode,
#     P.ProductDescription,
#     P.Price,
#     P.Quantity,
#     P.Weight_kg,
#     P.Volume_litre,
#     P.Length,
#     P.Width,
#     P.Height
# FROM Navigation_3NF AS N
# JOIN Products_3NF AS P ON P.PathID = N.PathID
# JOIN PackageContents_3NF AS PC ON P.ItemID = PC.ItemID
# JOIN Colours_3NF AS C ON P.ColourID = C.ColourID
# JOIN Brands_3NF AS B ON P.BrandID = B.BrandID
# JOIN Locations_3NF AS L ON P.LocationID = L.LocationID
# Out:
#  * sqlite:///bhejane.db
# 0 rows affected.
# []

# %% [markdown]
# ### <font color='turquoise'>Action: proceed with the insertion into `Transactions_3NF`.   </font>
#
# Follow previous proceedure, and checks.

# %%
# %%sql
# INSERT INTO "Transactions_3NF" ("CartID", "Barcode", "UserName", "UserID")
# SELECT DISTINCT "CartID", "Barcode", "UserName", "UserID"
# FROM Transactions_2NF;
# Out:
#  * sqlite:///bhejane.db
# 278 rows affected.
# []

# %% [markdown]
# ### <font color='turquoise'>Action: Investigate the DB.   </font>
#
# Note - the tables counts below are what you should arrive at. If you don't, reconsider how you have done the inserts above. Having the tables correctly formatted will allow to answer the questions more easily, and without errors.
#
# | Table Name | Count |
# | --- | --- |
# | Brands_3NF | 232 |
# | Carts_3NF |  190 |
# | Colours_3NF | 17 |
# | Locations_3NF | 2 |
# | Navigation_3NF | 396 |
# | PackageContents_3NF | 600 |
# | Products_3NF | 1214 |
# | Transactions_3NF | 275 |
# | Users_3NF | 158 |

# %%
# %%sql
#
# -- How many entries are here in each of the tables in the database now?
# select 'Products_3NF' as table_name, count(*) from Products_3NF
# UNION
# select 'Transactions_3NF' as table_name, count(*) from Transactions_3NF
# UNION
# select 'Users_3NF' as table_name, count(*) from Users_3NF
# UNION
# select 'Navigation_3NF' as table_name, count(*) from Navigation_3NF
# UNION
# select 'PackageContents_3NF' as table_name, count(*) from PackageContents_3NF
# UNION
# select 'Colours_3NF' as table_name, count(*) from Colours_3NF
# UNION
# select 'Brands_3NF' as table_name, count(*) from Brands_3NF
# UNION
# select 'Locations_3NF' as table_name, count(*) from Locations_3NF
# UNION
# select 'Carts_3NF' as table_name, count(*) from Carts_3NF
# Out:
#  * sqlite:///bhejane.db
# Done.
# [('Brands_3NF', 1214),
#  ('Carts_3NF', 192),
#  ('Colours_3NF', 1),
#  ('Locations_3NF', 1214),
#  ('Navigation_3NF', 1),
#  ('PackageContents_3NF', 1),
#  ('Products_3NF', 0),
#  ('Transactions_3NF', 278),
#  ('Users_3NF', 160)]

# %% [markdown]
# <a id='MCQ_questions'></a>
# ## 9. MCQ Questions
#
# Having completed the normalisation of the database, you may use the following cells to help you answer the MCQs for the predict.

# %% [markdown]
# Q1) How many unique products does the company have?

# %%
# %%sql
#
# SELECT ROUND(SUM(quantity), 0) AS TotalStock
# FROM Products;
# Out:
#  * sqlite:///bhejane.db
# Done.
# [(615016.0,)]

# %%
# %%sql
# select *
# from products
# Out:
#  * sqlite:///bhejane.db
# Done.
# [(None, None, None, '300507946', 493.0, 'Hikvision', 'Computers & Tablets / Smart Home & Connected Living / Home Security / Security Cameras', None, None, 'Hikvision 1080P 2MP Turbo HD IR Bullet Camera', None, 0.0, 'Limited (6 months)', None, '1 x Hikvision 1080P Bullet camera', 399.0),
#  (None, None, None, '300507946', 493.0, 'Hikvision', 'Computers & Tablets / Smart Home & Connected Living / Home Security / Security Cameras', None, None, 'Hikvision 1080P 2MP Turbo HD IR Bullet Camera', None, 0.0, 'Limited (6 months)', None, 'Manual', 399.0),
#  (None, None, None, '10325354918', 467.0, 'ZEE', 'Fashion / Accessories / Scarves', 'Grey', None, 'ZEE 3-in-1 Unisex Gaiter', None, 0.0, 'Limited (6 months)', None, None, 139.0),
#  (None, None, None, '27131187035', 275.0, 'Estee Lauder', 'Beauty / Luxury Beauty / Makeup / Face / Foundation', 'Fresco', 'South Africa', 'Estee Lauder Double Wear Stay In Place Makeup', None, 0.0, 'Non-Returnable', None, None, 655.0),
#  (None, None, None, '27131187035', 275.0, 'Estee Lauder', 'Beauty / Luxury Beauty / Shop By Brand / Estee Lauder / Makeup / Face / Foundation', 'Fresco', 'South Africa', 'Estee Lauder Double Wear Stay In Place Makeup', None, 0.0, 'Non-Returnable', None, None, 655.0),
#  (None, None, None, '27131187035', 275.0, 'Estee Lauder', 'Beauty / Makeup / Face / Foundation', 'Fresco', 'South Africa', 'Estee Lauder Double Wear Stay In Place Makeup', None, 0.0, 'Non-Returnable', None, None, 655.0),
#  (None, None, None, '39800085139', 247.0, 'Energizer', 'Cameras / Cameras & Lenses / Camera Accessories / General Purpose Batteries', None, 'South Africa', 'Energizer 3V CR2450 Lithium Coin Battery', None, 0.0, 'Limited (12 months)', None, None, 49.0),
#  (None, None, None, '43859499182', 386.0, 'Fellowes', 'Office & Stationery / Stationery / Office Supplies / Cleaning', None, 'South Africa', 'Fellowes HFC Free Air Duster - 350ml', None, 0.0, 'Limited (6 months)', None, '1 x 350ml Free Air Duster', 149.0),
#  (None, None, None, '43917915548', 338.0, 'WAHL', 'Health / Personal Care / Shaving & Hair Removal / Shaving Equipment & Devices / Body Groomers', None, 'South Africa', 'Wahl Home Pro Basic Corded 8 Piece Haircutting Kit', None, 0.0, 'Limited (6 months)', None, 'Wahl Home Pro Basic Corded 8 Piece Haircutting Kit', 149.0),
#  (None, None, None, '43917915548', 338.0, 'WAHL', 'Health / Personal Care / Shaving & Hair Removal / Shaving Equipment & Devices / Shavers', None, 'South Africa', 'Wahl Home Pro Basic Corded 8 Piece Haircutting Kit', None, 0.0, 'Limited (6 months)', None, 'Wahl Home Pro Basic Corded 8 Piece Haircutting Kit', 149.0),
#  (None, None, None, '43917915548', 338.0, 'WAHL', 'Beauty / Hair Care / Hair Styling Accessories / Clips & Barrettes', None, 'South Africa', 'Wahl Home Pro Basic Corded 8 Piece Haircutting Kit', None, 0.0, 'Limited (6 months)', None, 'Wahl Home Pro Basic Corded 8 Piece Haircutting Kit', 149.0),
#  (None, None, None, '43917915548', 338.0, 'WAHL', 'Health / Personal Care / Shaving & Hair Removal / Hair Removal', None, 'South Africa', 'Wahl Home Pro Basic Corded 8 Piece Haircutting Kit', None, 0.0, 'Limited (6 months)', None, 'Wahl Home Pro Basic Corded 8 Piece Haircutting Kit', 149.0),
#  (None, None, None, '43917915548', 338.0, 'WAHL', 'Beauty / Hair Care / Hair Styling Tools / Clippers', None, 'South Africa', 'Wahl Home Pro Basic Corded 8 Piece Haircutting Kit', None, 0.0, 'Limited (6 months)', None, 'Wahl Home Pro Basic Corded 8 Piece Haircutting Kit', 149.0),
#  (None, None, None, '43917963358', 375.0, 'WAHL', 'Beauty / Hair Care / Hair Styling Accessories / Clips & Barrettes', 'Red', 'South Africa', 'Wahl Easy Cut 15 Piece Complete Hair Clipper Kit', None, 0.0, 'Limited (6 months)', None, 'Wahl Easy Cut 15 Piece Complete Hair Clipper Kit', 199.0),
#  (None, None, None, '43917963358', 375.0, 'WAHL', 'Beauty / Hair Care / Hair Styling Tools / Clippers', 'Red', 'South Africa', 'Wahl Easy Cut 15 Piece Complete Hair Clipper Kit', None, 0.0, 'Limited (6 months)', None, 'Wahl Easy Cut 15 Piece Complete Hair Clipper Kit', 199.0),
#  ('8,5', '20,5', '26,5', '43917997155', 202.0, 'WAHL', 'Beauty / Hair Care / Hair Styling Accessories / Clips & Barrettes', None, 'South Africa', 'Wahl Smooth Cut Pro 10 Piece Hair Clipper Kit', None, 0.0, 'Limited (6 months)', None, None, 285.0),
#  ('8,5', '20,5', '26,5', '43917997155', 202.0, 'WAHL', 'Beauty / Hair Care / Hair Styling Tools / Clippers', None, 'South Africa', 'Wahl Smooth Cut Pro 10 Piece Hair Clipper Kit', None, 0.0, 'Limited (6 months)', None, None, 285.0),
#  (None, None, None, '80480300029', 291.0, 'Bombay Sapphire', 'Home & Kitchen / Liquor / Whiskey, Gin & Spirits / Gin', None, 'South Africa', 'Bombay Dry Gin ', 'Single', '0,75', 'Non-Returnable', None, '1 x Bombay - Dry Gin - 750ml', 199.0),
#  (None, None, None, '190198987563', 8.0, None, 'Cellphones & Wearables / Cellular Accessories / Cellphone Headsets', 'White', None, 'Generic AirPods for Apple (with Charging Case)', None, 0.0, 'Limited (6 months)', None, None, 255.0),
#  (None, None, None, '193808791192', 367.0, None, 'Computers & Tablets / Laptops / Notebooks', 'Black', None, 'HP Notebook 255 G7', None, 0.0, 'Limited (12 months)', None, None, 5199.0),
#  (None, None, None, '309974378017', 310.0, None, 'Beauty / Makeup / Lips / Lip Balm', None, 'South Africa', 'Revlon Kiss Balm Stain Exfoliating', None, 0.0, 'Non-Returnable', None, None, 62.0),
#  (None, None, None, '602693320795', 280.0, None, 'Computers & Tablets / Printers, Scanners & Copiers / Printer Accessories', None, None, 'Samsung MLT-D111L / 111L / D111 / 111 High Yield Black Compatible Toner', None, 0.0, 'Limited (6 months)', None, None, 230.0),
#  (None, None, None, '602693320801', 482.0, None, 'Computers & Tablets / Printers, Scanners & Copiers / Printer Accessories', None, None, 'Samsung MLT-D111S / 111S / D111 / 111 Black Compatible Toner', None, 0.0, 'Limited (6 months)', None, None, 227.0),
#  (None, None, None, '614143543241', 61.0, 'Digitronics', 'Cellphones & Wearables / Cellular Accessories / Cases & Covers', 'Transparent', None, 'Digitronics Protective Shockproof Gel Case for iPhone 11', None, 0.0, 'Limited (6 months)', None, '1x Digitronics Shockproof Clear Case', 119.0),
#  (None, None, None, '614143543289', 75.0, 'Digitronics', 'Cellphones & Wearables / Cellular Accessories / Screen Protectors', 'Transparent', None, 'Digitronics Protective Tempered Glass for iPhone 11', None, 0.0, 'Limited (6 months)', None, '1 x Digitronics Tempered Glass Screen Protector', 99.0),
#  (None, None, None, '614143543289', 75.0, 'Digitronics', 'Cellphones & Wearables / Cellular Accessories / Screen Protectors', 'Transparent', None, 'Digitronics Protective Tempered Glass for iPhone 11', None, 0.0, 'Limited (6 months)', None, '1 x Screen Protector Installation Pack', 99.0),
#  (None, None, None, '614143543746', 282.0, 'Digitronics', 'Cellphones & Wearables / Cellular Accessories / Screen Protectors', 'Transparent', None, 'Digitronics Protective Tempered Glass for Samsung Galaxy A30s / A50s / A50', None, 0.0, 'Limited (6 months)', None, '1x Digitronics Tempered Glass Screen Protector', 99.0),
#  (None, None, None, '614143543746', 282.0, 'Digitronics', 'Cellphones & Wearables / Cellular Accessories / Screen Protectors', 'Transparent', None, 'Digitronics Protective Tempered Glass for Samsung Galaxy A30s / A50s / A50', None, 0.0, 'Limited (6 months)', None, '1x Screen Protector Installation Pack', 99.0),
#  (None, None, None, '617566827448', 284.0, 'Intelli-Vision Technology', 'TV, Audio & Video / TV & Audio Accessories / TV Accessories / Adapters', None, None, 'HDMI To VGA Adaptor', None, 0.0, 'Limited (6 months)', None, '1 x hdmi to VGA Adaptor', 154.0),
#  (None, None, None, '617566827448', 284.0, 'Intelli-Vision Technology', 'TV, Audio & Video / TV & Audio Accessories / Cables', None, None, 'HDMI To VGA Adaptor', None, 0.0, 'Limited (6 months)', None, '1 x hdmi to VGA Adaptor', 154.0),
#  (None, None, None, '617566827448', 284.0, 'Intelli-Vision Technology', 'TV, Audio & Video / TV Accessories / Adapters', None, None, 'HDMI To VGA Adaptor', None, 0.0, 'Limited (6 months)', None, '1 x hdmi to VGA Adaptor', 154.0),
#  (None, None, None, '617566827837', 260.0, None, 'Garden, Pool & Patio / Patio / Patio Furniture / Patio Tables', None, None, 'ZYS 1,8m Folding Table - White', None, 0.0, 'Limited (6 months)', None, '1 x Folding Table', 699.0),
#  (None, None, None, '619659000431', 243.0, 'SanDisk', 'Computers & Tablets / Drives & Storage / Flash Drives', None, None, 'Sandisk Cruzer Blade 16GB - Flash Drive', None, '1,17816', 'Limited (24 months)', None, '1 X SanDisk Cruzer Blade USB Flash Drive 16GB', 59.0),
#  (None, None, None, '619659066888', 216.0, 'SanDisk', 'Computers & Tablets / Laptop Accessories / Memory Cards', None, 'South Africa', 'SanDisk 16GB 10 MB/s Micro UHS-l SDHC C 4 SDSDQM-016G-B35A', None, 0.0, 'Limited (60 months)', None, '1 x SDSDQM-016G-B35A', 69.0),
#  (None, None, None, '619659066888', 216.0, 'SanDisk', 'Computers & Tablets / Laptop Accessories / Memory Cards', None, 'South Africa', 'SanDisk 16GB 10 MB/s Micro UHS-l SDHC C 4 SDSDQM-016G-B35A', None, 0.0, 'Limited (60 months)', None, '1 x SD Adapter', 69.0),
#  (None, None, None, '619659066888', 216.0, 'SanDisk', 'Cameras / Cameras & Lenses / Camera Accessories / Memory', None, 'South Africa', 'SanDisk 16GB 10 MB/s Micro UHS-l SDHC C 4 SDSDQM-016G-B35A', None, 0.0, 'Limited (60 months)', None, '1 x SDSDQM-016G-B35A', 69.0),
#  (None, None, None, '619659066888', 216.0, 'SanDisk', 'Cameras / Cameras & Lenses / Camera Accessories / Memory', None, 'South Africa', 'SanDisk 16GB 10 MB/s Micro UHS-l SDHC C 4 SDSDQM-016G-B35A', None, 0.0, 'Limited (60 months)', None, '1 x SD Adapter', 69.0),
#  (None, None, None, '619659066888', 216.0, 'SanDisk', 'Cellphones & Wearables / Cellular Accessories / Memory Cards', None, 'South Africa', 'SanDisk 16GB 10 MB/s Micro UHS-l SDHC C 4 SDSDQM-016G-B35A', None, 0.0, 'Limited (60 months)', None, '1 x SDSDQM-016G-B35A', 69.0),
#  (None, None, None, '619659066888', 216.0, 'SanDisk', 'Cellphones & Wearables / Cellular Accessories / Memory Cards', None, 'South Africa', 'SanDisk 16GB 10 MB/s Micro UHS-l SDHC C 4 SDSDQM-016G-B35A', None, 0.0, 'Limited (60 months)', None, '1 x SD Adapter', 69.0),
#  (None, None, None, '619659066918', 59.0, 'SanDisk', 'Computers & Tablets / Laptop Accessories / Memory Cards', None, 'South Africa', 'SanDisk 32GB Micro UHS-l SDHC C 4 SDSDQM-032G-B35A', None, 0.0, 'Limited (60 months)', None, '1 x SDSDQM-032G-B35A', 89.0),
#  (None, None, None, '619659066918', 59.0, 'SanDisk', 'Computers & Tablets / Laptop Accessories / Memory Cards', None, 'South Africa', 'SanDisk 32GB Micro UHS-l SDHC C 4 SDSDQM-032G-B35A', None, 0.0, 'Limited (60 months)', None, '1 x Adapter', 89.0),
#  (None, None, None, '619659066918', 59.0, 'SanDisk', 'Cameras / Cameras & Lenses / Camera Accessories / Memory', None, 'South Africa', 'SanDisk 32GB Micro UHS-l SDHC C 4 SDSDQM-032G-B35A', None, 0.0, 'Limited (60 months)', None, '1 x SDSDQM-032G-B35A', 89.0),
#  (None, None, None, '619659066918', 59.0, 'SanDisk', 'Cameras / Cameras & Lenses / Camera Accessories / Memory', None, 'South Africa', 'SanDisk 32GB Micro UHS-l SDHC C 4 SDSDQM-032G-B35A', None, 0.0, 'Limited (60 months)', None, '1 x Adapter', 89.0),
#  (None, None, None, '619659066918', 59.0, 'SanDisk', 'Cellphones & Wearables / Cellular Accessories / Memory Cards', None, 'South Africa', 'SanDisk 32GB Micro UHS-l SDHC C 4 SDSDQM-032G-B35A', None, 0.0, 'Limited (60 months)', None, '1 x SDSDQM-032G-B35A', 89.0),
#  (None, None, None, '619659066918', 59.0, 'SanDisk', 'Cellphones & Wearables / Cellular Accessories / Memory Cards', None, 'South Africa', 'SanDisk 32GB Micro UHS-l SDHC C 4 SDSDQM-032G-B35A', None, 0.0, 'Limited (60 months)', None, '1 x Adapter', 89.0),
#  (None, None, None, '619659069193', 169.0, None, 'Computers & Tablets / Drives & Storage / Flash Drives', None, None, 'SanDisk Cruzer Blade 32GB - USB Flash drive', None, 0.0, 'Limited (6 months)', None, None, 75.0),
#  (None, None, None, '619659097318', 12.0, 'SanDisk', 'Computers & Tablets / Drives & Storage / Flash Drives', None, 'South Africa', 'Sandisk Cruzer Blade 64GB Flash Drive', None, 0.0, 'Limited (6 months)', None, '1 X USB Cruzer Blade', 169.0),
#  (None, None, None, '619659137175', 291.0, 'SanDisk', 'Computers & Tablets / Laptop Accessories / Memory Cards', 'Black', 'South Africa', 'SanDisk 64GB 80 MB/s Ultra SD Card UHS-l SDXC C10', None, 0.0, 'Limited (120 months)', None, '1 x SDSDUNC-064G-GN6IN', 229.0),
#  (None, None, None, '619659137175', 291.0, 'SanDisk', 'Cameras / Cameras & Lenses / Camera Accessories / Memory', 'Black', 'South Africa', 'SanDisk 64GB 80 MB/s Ultra SD Card UHS-l SDXC C10', None, 0.0, 'Limited (120 months)', None, '1 x SDSDUNC-064G-GN6IN', 229.0),
#  (None, None, None, '619659141059', 320.0, 'SanDisk', 'Computers & Tablets / Drives & Storage / Flash Drives', None, 'South Africa', 'SanDisk Cruzer Blade 16GB USB Flash Drive - Electric Blue', None, 0.0, 'Limited (60 months)', None, '1 x SANDISK CRUZER BLADE 16GB USB2,0 ELECTRIC BLUE FLASH DRIVE', 75.0),
#  (None, None, None, '619659141066', 29.0, 'SanDisk', 'Computers & Tablets / Drives & Storage / Flash Drives', None, 'South Africa', 'SanDisk Cruzer Blade 16GB USB Flash Drive - Electric Pink', None, 0.0, 'Limited (60 months)', None, '1 x SANDISK CRUZER BLADE 16GB USB2,0 ELECTRIC PINK FLASH DRIVE', 59.0),
#  (None, None, None, '619659141080', 205.0, 'SanDisk', 'Computers & Tablets / Drives & Storage / Flash Drives', None, 'South Africa', 'SanDisk Cruzer Blade 16GB USB Flash Drive - Electric Green', None, 0.0, 'Limited (60 months)', None, '1 x SANDISK CRUZER BLADE 16GB USB2,0 ELECTRIC GREEN FLASH DRIVE', 59.0),
#  (None, None, None, '619659149598', 59.0, 'SanDisk', 'Computers & Tablets / Drives & Storage / Flash Drives', 'Grey', None, 'Sandisk Ultra 32GB USB3,0 Dual Flash Drive', None, 0.0, 'Limited (6 months)', None, '1 X USB Ultra Dual', 129.0),
#  (None, None, None, '619659160401', 85.0, 'SanDisk', 'Computers & Tablets / Laptop Accessories / Memory Cards', None, 'South Africa', 'SanDisk 128GB 100 MB/s Ultra Micro UHS-I SDXC C10', None, 0.0, 'Limited (120 months)', None, 'Memory card', 365.0),
#  (None, None, None, '619659160401', 85.0, 'SanDisk', 'Cameras / Cameras & Lenses / Camera Accessories / Memory', None, 'South Africa', 'SanDisk 128GB 100 MB/s Ultra Micro UHS-I SDXC C10', None, 0.0, 'Limited (120 months)', None, 'Memory card', 365.0),
#  (None, None, None, '619659160401', 85.0, 'SanDisk', 'Cellphones & Wearables / Cellular Accessories / Memory Cards', None, 'South Africa', 'SanDisk 128GB 100 MB/s Ultra Micro UHS-I SDXC C10', None, 0.0, 'Limited (120 months)', None, 'Memory card', 365.0),
#  (None, None, None, '619659161354', 250.0, 'SanDisk', 'Computers & Tablets / Laptop Accessories / Memory Cards', None, 'South Africa', 'SanDisk 16GB 98 MB/s Ultra Micro UHS-l SDHC C10', None, 0.0, 'Limited (120 months)', None, 'Memory card', 89.0),
#  (None, None, None, '619659161354', 250.0, 'SanDisk', 'Cameras / Cameras & Lenses / Camera Accessories / Memory', None, 'South Africa', 'SanDisk 16GB 98 MB/s Ultra Micro UHS-l SDHC C10', None, 0.0, 'Limited (120 months)', None, 'Memory card', 89.0),
#  (None, None, None, '619659161354', 250.0, 'SanDisk', 'Cellphones & Wearables / Cellular Accessories / Memory Cards', None, 'South Africa', 'SanDisk 16GB 98 MB/s Ultra Micro UHS-l SDHC C10', None, 0.0, 'Limited (120 months)', None, 'Memory card', 89.0),
#  (None, None, None, '619659161514', 419.0, 'SanDisk', 'Computers & Tablets / Laptop Accessories / Memory Cards', None, 'South Africa', 'SanDisk 64GB 98 MB/s Ultra Micro UHS-l SDXC C10', None, 0.0, 'Limited (120 months)', None, 'Memory card', 189.0),
#  (None, None, None, '619659161514', 419.0, 'SanDisk', 'Cameras / Cameras & Lenses / Camera Accessories / Memory', None, 'South Africa', 'SanDisk 64GB 98 MB/s Ultra Micro UHS-l SDXC C10', None, 0.0, 'Limited (120 months)', None, 'Memory card', 189.0),
#  (None, None, None, '619659161514', 419.0, 'SanDisk', 'Cellphones & Wearables / Cellular Accessories / Memory Cards', None, 'South Africa', 'SanDisk 64GB 98 MB/s Ultra Micro UHS-l SDXC C10', None, 0.0, 'Limited (120 months)', None, 'Memory card', 189.0),
#  (None, None, None, '619659161644', 353.0, 'SanDisk', 'Computers & Tablets / Laptop Accessories / Memory Cards', None, 'South Africa', 'SanDisk 32GB Ultra Micro UHS-I SDHC C10', None, 0.0, 'Limited (60 months)', None, '1 x 32GB MicroSDHC SanDisk Ultra Android', 89.0),
#  (None, None, None, '619659161644', 353.0, 'SanDisk', 'Computers & Tablets / Laptop Accessories / Memory Cards', None, 'South Africa', 'SanDisk 32GB Ultra Micro UHS-I SDHC C10', None, 0.0, 'Limited (60 months)', None, '1 x Adapter', 89.0),
#  (None, None, None, '619659161644', 353.0, 'SanDisk', 'Cameras / Cameras & Lenses / Camera Accessories / Memory', None, 'South Africa', 'SanDisk 32GB Ultra Micro UHS-I SDHC C10', None, 0.0, 'Limited (60 months)', None, '1 x 32GB MicroSDHC SanDisk Ultra Android', 89.0),
#  (None, None, None, '619659161644', 353.0, 'SanDisk', 'Cameras / Cameras & Lenses / Camera Accessories / Memory', None, 'South Africa', 'SanDisk 32GB Ultra Micro UHS-I SDHC C10', None, 0.0, 'Limited (60 months)', None, '1 x Adapter', 89.0),
#  (None, None, None, '619659161644', 353.0, 'SanDisk', 'Cellphones & Wearables / Cellular Accessories / Memory Cards', None, 'South Africa', 'SanDisk 32GB Ultra Micro UHS-I SDHC C10', None, 0.0, 'Limited (60 months)', None, '1 x 32GB MicroSDHC SanDisk Ultra Android', 89.0),
#  (None, None, None, '619659161644', 353.0, 'SanDisk', 'Cellphones & Wearables / Cellular Accessories / Memory Cards', None, 'South Africa', 'SanDisk 32GB Ultra Micro UHS-I SDHC C10', None, 0.0, 'Limited (60 months)', None, '1 x Adapter', 89.0),
#  (None, None, None, '619659161927', 13.0, 'SanDisk', 'Computers & Tablets / Laptop Accessories / Memory Cards', None, 'South Africa', 'SanDisk 64GB 80 MB/s Ultra Micro UHS-l SDXC C10', None, 0.0, 'Limited (120 months)', None, None, 185.0),
#  (None, None, None, '619659161927', 13.0, 'SanDisk', 'Cameras / Cameras & Lenses / Camera Accessories / Memory', None, 'South Africa', 'SanDisk 64GB 80 MB/s Ultra Micro UHS-l SDXC C10', None, 0.0, 'Limited (120 months)', None, None, 185.0),
#  (None, None, None, '619659161927', 13.0, 'SanDisk', 'Cellphones & Wearables / Cellular Accessories / Memory Cards', None, 'South Africa', 'SanDisk 64GB 80 MB/s Ultra Micro UHS-l SDXC C10', None, 0.0, 'Limited (120 months)', None, None, 185.0),
#  ('0,635', '10,16', '15,24', '619659169817', 409.0, 'SanDisk', 'Computers & Tablets / Laptop Accessories / Memory Cards', None, 'South Africa', 'SanDisk 128GB 170 MB/s Extreme Pro Micro SDXC', None, 0.0, 'Limited (180 months)', None, None, 599.0),
#  ('0,635', '10,16', '15,24', '619659169817', 409.0, 'SanDisk', 'Cameras / Cameras & Lenses / Camera Accessories / Memory', None, 'South Africa', 'SanDisk 128GB 170 MB/s Extreme Pro Micro SDXC', None, 0.0, 'Limited (180 months)', None, None, 599.0),
#  ('0,635', '10,16', '15,24', '619659169817', 409.0, 'SanDisk', 'Cellphones & Wearables / Cellular Accessories / Memory Cards', None, 'South Africa', 'SanDisk 128GB 170 MB/s Extreme Pro Micro SDXC', None, 0.0, 'Limited (180 months)', None, None, 599.0),
#  ('0,49', '10,1', '15,2', '619659169893', 220.0, 'SanDisk', 'Computers & Tablets / Laptop Accessories / Memory Cards', None, 'South Africa', 'Sandisk Ultra Android Microsdxc 128Gb 80Mb/S Class 10', None, 0.0, 'Limited (120 months)', None, None, 349.0),
#  ('0,49', '10,1', '15,2', '619659169893', 220.0, 'SanDisk', 'Cameras / Cameras & Lenses / Camera Accessories / Memory', None, 'South Africa', 'Sandisk Ultra Android Microsdxc 128Gb 80Mb/S Class 10', None, 0.0, 'Limited (120 months)', None, None, 349.0),
#  ('0,49', '10,1', '15,2', '619659169893', 220.0, 'SanDisk', 'Cellphones & Wearables / Cellular Accessories / Memory Cards', None, 'South Africa', 'Sandisk Ultra Android Microsdxc 128Gb 80Mb/S Class 10', None, 0.0, 'Limited (120 months)', None, None, 349.0),
#  (None, None, None, '638142992763', 44.0, 'Rose en Bos', 'Health / Personal Care / Lip & Skin Care / Body Care / Soaps & Body Wash', None, 'South Africa', 'Rose en Bos Charcoal Soap - 100g', None, 0.0, 'Limited (6 months)', None, None, 44.0),
#  (None, None, None, '638142992763', 44.0, 'Rose en Bos', 'Beauty / Body Care / Soap & Body Wash', None, 'South Africa', 'Rose en Bos Charcoal Soap - 100g', None, 0.0, 'Limited (6 months)', None, None, 44.0),
#  (11.0, 4.0, 4.0, '644287927652', 423.0, 'African Beauty Secret', 'Beauty / Skin Care / Treatments', None, None, 'Hyaluronic Acid Serum', None, '0,03', 'Limited (6 months)', None, '30 ml Hyaluronic Acid', 179.0),
#  (None, None, None, '658921935286', 423.0, None, 'Cameras / Cameras & Lenses / Camera Accessories / General Purpose Batteries', None, None, 'Samsung 30Q 18650 3000mah', None, 0.0, 'Limited (6 months)', None, '1 x 30Q Battery', 192.0),
#  ('10,6', '23,3', '0,5', '659438715200', 244.0, None, 'Computers & Tablets / Laptop Accessories / Mounts & Stands', 'Black', None, 'Eco-friendly EEZIGO Portable Laptop Stand', None, 0.0, 'Limited (6 months)', None, '1 x Laptop stand', 179.0),
#  ('10,6', '23,3', '0,5', '659438715200', 244.0, None, 'Computers & Tablets / Laptop Accessories / Mounts & Stands', 'Black', None, 'Eco-friendly EEZIGO Portable Laptop Stand', None, 0.0, 'Limited (6 months)', None, '4 x Self-adhesive hook and loop pads', 179.0),
#  ('10,6', '23,3', '0,5', '659438715200', 244.0, None, 'Computers & Tablets / Laptop Accessories / Mounts & Stands', 'Black', None, 'Eco-friendly EEZIGO Portable Laptop Stand', None, 0.0, 'Limited (6 months)', None, '2 x Non slip rubber pads', 179.0),
#  ('10,6', '23,3', '0,5', '659438715200', 244.0, None, 'Computers & Tablets / Laptop Accessories / Mounts & Stands', 'Black', None, 'Eco-friendly EEZIGO Portable Laptop Stand', None, 0.0, 'Limited (6 months)', None, '1 x Instruction pamphlet', 179.0),
#  (None, None, None, '711719870258', 421.0, 'Sony Playstation', 'Gaming / Gaming Accessories / Controllers', 'Black', 'South Africa', 'PS4 Dualshock 4 Controller - Black V2 (PS4)', None, '2,94112', 'Limited (12 months)', None, '1 x PS4 controller', 1159.0),
#  (None, None, None, '718037779911', 427.0, 'Western Digital', 'Computers & Tablets / Drives & Storage / Internal HDD', None, 'South Africa', 'WD Blue 1TB 3,5" SATA 6Gb/s 64MB Internal Hard Drive', None, 0.0, 'Limited (24 months)', None, '1 x WD Blue 1TB Desktop Hard Drive', 729.0),
#  ('8,2', '11,05', '1,5', '718037855448', 499.0, 'Western Digital', 'Computers & Tablets / Drives & Storage / Portable HDD', 'Black', 'South Africa', 'WD Elements Portable 1TB USB 3,0', None, 0.0, 'Limited (24 months)', None, '1 x WD Element 1TB External HDD', 840.0),
#  ('8,2', '11,05', '1,5', '718037855448', 499.0, 'Western Digital', 'Computers & Tablets / Drives & Storage / Portable HDD', 'Black', 'South Africa', 'WD Elements Portable 1TB USB 3,0', None, 0.0, 'Limited (24 months)', None, '1 x USB3,0 Cable', 840.0),
#  ('8,2', '11,05', '1,5', '718037855448', 499.0, 'Western Digital', 'Computers & Tablets / Drives & Storage / Portable HDD', 'Black', 'South Africa', 'WD Elements Portable 1TB USB 3,0', None, 0.0, 'Limited (24 months)', None, '1 x User Guide', 840.0),
#  (None, None, None, '718037858494', 332.0, 'Western Digital', 'Computers & Tablets / Drives & Storage / Solid State Drive (SSD)', None, 'South Africa', 'Western Digital Green 240Gb 2,5" SATA SSD', None, 0.0, 'Limited (36 months)', None, '1 x WD GREEN 240GB 2,5" SATA3 3D NAND SSD', 625.0),
#  (None, None, None, '741311301174', 24.0, 'RCT', 'Computers & Tablets / Smart Home & Connected Living / Smart Energy Solutions / Uninterrupted Power Supply (UPS)', 'Black', 'South Africa', 'RCT 2000VA Line Interactive UPS', None, 0.0, 'Limited (12 months)', None, '1 x UPS', 1999.0),
#  ('5,26', '5,26', '10,72', '781159522031', 444.0, 'orange apple', 'Health / Health Care / First Aid / First Aid Supplies / Antiseptics & Antibacterials', 'White', 'South Africa', 'Omniprotect Aerosol Sanitiser 120ml - 70% Alcohol', None, 0.0, 'Non-Returnable', None, 'Aersosol Sanitizing spray - single unit 120ml,', 50.0),
#  (None, None, None, '781718329101', 266.0, 'Google', 'TV, Audio & Video / Video / Media Players', 'Black', None, 'Google Chromecast 3rd Gen 2018 Black Parallel Import (OEM Packaging)', None, 0.0, 'Limited (12 months)', None, '1x Google Chromecast 3,0 (2018 Model) With HDMI connection attached', 935.0),
#  (None, None, None, '781718329101', 266.0, 'Google', 'TV, Audio & Video / Video / Media Players', 'Black', None, 'Google Chromecast 3rd Gen 2018 Black Parallel Import (OEM Packaging)', None, 0.0, 'Limited (12 months)', None, '1x USB-micro USB Power Cable', 935.0),
#  (None, None, None, '781718445863', 60.0, 'Victoria Gin', 'Home & Kitchen / Liquor / Whiskey, Gin & Spirits / Gin', None, 'South Africa', 'Victoria Limited Edition Orange Blossom & Rose Hip by Minki - 750ml', 'Single', '0,75', 'Non-Returnable', None, '1 x 750ml', 299.0),
#  (None, None, None, '782376292899', 227.0, 'LDNIO', 'Cellphones & Wearables / Cellular Accessories / Cellphone Cables', 'White', None, 'iPhone USB Charging Cable for iPhone 5 & 6 - White', None, '7,8576', 'Limited (6 months)', None, 'Charge / Sync Cable', 43.0),
#  (None, None, None, '790069435478', 444.0, 'D-Link', 'Computers & Tablets / Networking / USB Networking Device', None, 'South Africa', 'D-Link DWM-222 4G LTE USB Adapter', None, 0.0, 'Limited (36 months)', None, '1 x D-Link DWM-222 4G LTE USB Adapter', 585.0),
#  (None, None, None, '815592024309', 89.0, 'Ematic', 'TV, Audio & Video / Video / Media Players', 'Black', None, 'Ematic AGT419 4K (UltraHD) Quad Core Android TV Box (Google and Netflix Certified)', None, 0.0, 'Limited (12 months)', None, 'Android TV Box', 1399.0),
#  (None, None, None, '815592024309', 89.0, 'Ematic', 'TV, Audio & Video / Video / Media Players', 'Black', None, 'Ematic AGT419 4K (UltraHD) Quad Core Android TV Box (Google and Netflix Certified)', None, 0.0, 'Limited (12 months)', None, 'Bluetooth Remote with Voice Search', 1399.0),
#  (None, None, None, '815592024309', 89.0, 'Ematic', 'TV, Audio & Video / Video / Media Players', 'Black', None, 'Ematic AGT419 4K (UltraHD) Quad Core Android TV Box (Google and Netflix Certified)', None, 0.0, 'Limited (12 months)', None, 'Power adapter', 1399.0),
#  (None, None, None, '815592024309', 89.0, 'Ematic', 'TV, Audio & Video / Video / Media Players', 'Black', None, 'Ematic AGT419 4K (UltraHD) Quad Core Android TV Box (Google and Netflix Certified)', None, 0.0, 'Limited (12 months)', None, 'HDMI cable', 1399.0),
#  (None, None, None, '815592024309', 89.0, 'Ematic', 'TV, Audio & Video / Video / Media Players', 'Black', None, 'Ematic AGT419 4K (UltraHD) Quad Core Android TV Box (Google and Netflix Certified)', None, 0.0, 'Limited (12 months)', None, 'Quick start guide', 1399.0),
#  (None, None, None, '815592024309', 89.0, 'Ematic', 'TV, Audio & Video / Video / Media Players', 'Black', None, 'Ematic AGT419 4K (UltraHD) Quad Core Android TV Box (Google and Netflix Certified)', None, 0.0, 'Limited (12 months)', None, '2 x AAA Batteries', 1399.0),
#  (None, None, None, '834266002368', 282.0, None, 'Health / Health Care / First Aid / First Aid Supplies / Antiseptics & Antibacterials', None, None, 'Aerosol Sanitizing Spray 120ml - 6 Pack', None, 0.0, 'Limited (6 months)', None, None, 242.0),
#  (None, None, None, '845973070199', 164.0, 'TP-Link', 'Computers & Tablets / Networking / Extenders & Repeaters', 'White', 'South Africa', 'TP-LINK TL-WA850RE 300Mbps Wi-Fi Range Extender', None, '15,22473', 'Limited (12 months)', None, '300Mbps Universal Wi-Fi Range Extender TL-WA850RE', 525.0),
#  (None, None, None, '845973070199', 164.0, 'TP-Link', 'Computers & Tablets / Networking / Extenders & Repeaters', 'White', 'South Africa', 'TP-LINK TL-WA850RE 300Mbps Wi-Fi Range Extender', None, '15,22473', 'Limited (12 months)', None, 'Quick Installation Guide', 525.0),
#  (None, None, None, '867408104079', 16.0, None, 'Garden, Pool & Patio / Home Improvement / Lighting & Electrical / Light Bulbs & Lighting', None, None, 'COB Solar Power Motion Sensor Wall Light ( Pack 4 )', None, 0.0, 'Limited (6 months)', None, None, 190.0),
#  (None, None, None, '884392580773', 210.0, 'Safety 1st', 'Baby & Toddler / Mom & Baby Care / Bathing & Grooming / Combs & Brushes', None, 'South Africa', 'Safety 1st - Baby Care Basics', None, '1,11766', 'Limited (6 months)', None, None, 109.0),
#  (None, None, None, '884392580773', 210.0, 'Safety 1st', 'Baby & Toddler / Mom & Baby Care / Nail Care / Grooming Sets', None, 'South Africa', 'Safety 1st - Baby Care Basics', None, '1,11766', 'Limited (6 months)', None, None, 109.0),
#  (None, None, None, '885370239386', 345.0, None, 'Gaming / Gaming Accessories / Controllers', None, None, 'X-360 Wired Controller Gamepad Compatible with Xbox 360 Game Console and PC', None, 0.0, 'Limited (6 months)', None, '1 x X-360 Wired Controller Gamepad Compatible with Xbox 360 Game Console and PC', 273.0),
#  (None, None, None, '885370727029', 368.0, 'Microsoft', 'Computers & Tablets / Laptop Accessories / Mice', 'Black', 'South Africa', 'Microsoft Wireless Mobile Mouse 1850 - Black', None, 0.0, 'Limited (36 months)', None, '1 x Microsoft Wireless Mobile Mouse 1850', 249.0),
#  (None, None, None, '885370727029', 368.0, 'Microsoft', 'Computers & Tablets / Peripherals / Mouse & Presentation', 'Black', 'South Africa', 'Microsoft Wireless Mobile Mouse 1850 - Black', None, 0.0, 'Limited (36 months)', None, '1 x Microsoft Wireless Mobile Mouse 1850', 249.0),
#  (None, None, None, '886112546052', 415.0, 'HP', 'Office & Stationery / Office / Office Consumables / Ink Cartridges', None, 'South Africa', 'HP 650 Tri-Colour Ink Cartridge', None, 0.0, 'Limited (6 months)', None, '1 x Cartridge', 249.0),
#  (None, None, None, '887961919509', 126.0, 'Barbie', 'Toys / Indoor Play / Dolls & Accessories / Fashion Dolls / Barbie', None, 'South Africa', 'Barbie Colour Reveal Doll with 7 Surprises - Blindbox', None, 0.0, 'Limited (6 months)', None, '1 x Barbie Colour Reveal doll with surprise look and colour-change face and sculpted hair', 379.0),
#  (None, None, None, '887961919509', 126.0, 'Barbie', 'Toys / Indoor Play / Dolls & Accessories / Fashion Dolls / Barbie', None, 'South Africa', 'Barbie Colour Reveal Doll with 7 Surprises - Blindbox', None, 0.0, 'Limited (6 months)', None, '1 x Wig', 379.0),
#  (None, None, None, '887961919509', 126.0, 'Barbie', 'Toys / Indoor Play / Dolls & Accessories / Fashion Dolls / Barbie', None, 'South Africa', 'Barbie Colour Reveal Doll with 7 Surprises - Blindbox', None, 0.0, 'Limited (6 months)', None, '1 x Skirt', 379.0),
#  (None, None, None, '887961919509', 126.0, 'Barbie', 'Toys / Indoor Play / Dolls & Accessories / Fashion Dolls / Barbie', None, 'South Africa', 'Barbie Colour Reveal Doll with 7 Surprises - Blindbox', None, 0.0, 'Limited (6 months)', None, '1 x Pair of shoes', 379.0),
#  (None, None, None, '887961919509', 126.0, 'Barbie', 'Toys / Indoor Play / Dolls & Accessories / Fashion Dolls / Barbie', None, 'South Africa', 'Barbie Colour Reveal Doll with 7 Surprises - Blindbox', None, 0.0, 'Limited (6 months)', None, '1 x Sponge', 379.0),
#  (None, None, None, '888793803158', 38.0, 'HP', 'Office & Stationery / Office / Office Consumables / Ink Cartridges', None, 'South Africa', 'HP 123 Tri-Colour Ink Cartridge', None, 0.0, 'Limited (6 months)', None, '1 x Cartridge', 299.0),
#  (None, None, None, '888793803172', 231.0, 'HP', 'Office & Stationery / Office / Office Consumables / Ink Cartridges', 'Black', 'South Africa', 'HP 123 Black Ink Cartridge', None, 0.0, 'Limited (6 months)', None, '1 x Cartridge', 249.0),
#  (None, None, None, '2000001014929', 287.0, 'Unbranded', 'Health / Health Care / First Aid / First Aid Supplies / Gloves & Masks', 'Black', 'South Africa', '100% Cotton Face Mask - Multi- Coloured Pack of 5', None, 0.0, 'Non-Returnable', None, '5 x Multi-Pack face masks', 119.0),
#  (None, None, None, '2000001014929', 287.0, 'Unbranded', 'Fashion / Accessories', 'Black', 'South Africa', '100% Cotton Face Mask - Multi- Coloured Pack of 5', None, 0.0, 'Non-Returnable', None, '5 x Multi-Pack face masks', 119.0),
#  (None, None, None, '2000001014929', 287.0, 'Unbranded', 'Fashion / Clothing', 'Black', 'South Africa', '100% Cotton Face Mask - Multi- Coloured Pack of 5', None, 0.0, 'Non-Returnable', None, '5 x Multi-Pack face masks', 119.0),
#  (None, None, None, '2000001014935', 149.0, 'Unbranded', 'Health / Health Care / First Aid / First Aid Supplies / Gloves & Masks', 'White', 'South Africa', '100% Cotton 3-ply Face Mask - White', None, 0.0, 'Non-Returnable', None, '1 x Cotton facial mask', 20.0),
#  (None, None, None, '2000001014935', 149.0, 'Unbranded', 'Fashion / Accessories', 'White', 'South Africa', '100% Cotton 3-ply Face Mask - White', None, 0.0, 'Non-Returnable', None, '1 x Cotton facial mask', 20.0),
#  (None, None, None, '2000001014935', 149.0, 'Unbranded', 'Fashion / Clothing', 'White', 'South Africa', '100% Cotton 3-ply Face Mask - White', None, 0.0, 'Non-Returnable', None, '1 x Cotton facial mask', 20.0),
#  (None, None, None, '2000001014937', 422.0, 'Unbranded', 'Health / Health Care / First Aid / First Aid Supplies / Gloves & Masks', 'Blue', 'South Africa', '100% Cotton 3-ply Face Mask - Navy', None, 0.0, 'Non-Returnable', None, '1 x Cotton facial mask', 20.0),
#  (None, None, None, '2000001014937', 422.0, 'Unbranded', 'Fashion / Accessories', 'Blue', 'South Africa', '100% Cotton 3-ply Face Mask - Navy', None, 0.0, 'Non-Returnable', None, '1 x Cotton facial mask', 20.0),
#  (None, None, None, '2000001014937', 422.0, 'Unbranded', 'Fashion / Clothing', 'Blue', 'South Africa', '100% Cotton 3-ply Face Mask - Navy', None, 0.0, 'Non-Returnable', None, '1 x Cotton facial mask', 20.0),
#  (None, None, None, '3141725003277', 185.0, 'HP', 'Office & Stationery / Stationery / Office Supplies / Paper', None, 'South Africa', 'HP: A4 Everyday Paper - White Copy Printer Paper - Box', None, 0.0, 'Limited (6 months)', None, 'HP A4 Everyday Paper - White Copy Printer Paper - Box', 299.0),
#  (None, None, None, '3141725003277', 185.0, 'HP', 'Office & Stationery / Office / Office Consumables / Paper / Printer Paper', None, 'South Africa', 'HP: A4 Everyday Paper - White Copy Printer Paper - Box', None, 0.0, 'Limited (6 months)', None, 'HP A4 Everyday Paper - White Copy Printer Paper - Box', 299.0),
#  (21.0, 30.0, '12,6', '3574661422398', 299.0, 'Johnson & Johnson', 'Baby & Toddler / Nappies & Changing / Wipes', None, 'South Africa', 'Johnsons, Wipes, Gentle All Over Wipes, Pack Of 432 Wipes', 'Pack', 0.0, 'Supplier (18 months)', '2,515', "6 x 72's Gentle All Over Wipes", 129.0),
#  (None, None, None, '4007817432228', 223.0, 'Staedtler', 'Office & Stationery / Stationery / Student Supplies / Colouring / Colouring Pens & Markers', None, 'South Africa', 'Staedtler Ballpoint Pens - Assorted Colours', None, '4,97265', 'Limited (6 months)', None, None, 36.0),
#  (None, None, None, '4007817432228', 223.0, 'Staedtler', 'Office & Stationery / Stationery / Office Supplies / Writing Tools / Fine Writing / Ballpoint Pens', None, 'South Africa', 'Staedtler Ballpoint Pens - Assorted Colours', None, '4,97265', 'Limited (6 months)', None, None, 36.0),
#  (None, None, None, '4007817432228', 223.0, 'Staedtler', 'Office & Stationery / Stationery / Office Supplies / Writing Tools / Pens & Refills / Pen Sets', None, 'South Africa', 'Staedtler Ballpoint Pens - Assorted Colours', None, '4,97265', 'Limited (6 months)', None, None, 36.0),
#  (None, None, None, '4007817432228', 223.0, 'Staedtler', 'Office & Stationery / Stationery / Office Supplies / Writing Tools / Pens & Refills / Ballpoint Pens', None, 'South Africa', 'Staedtler Ballpoint Pens - Assorted Colours', None, '4,97265', 'Limited (6 months)', None, None, 36.0),
#  (None, None, None, '4007817432228', 223.0, 'Staedtler', 'Office & Stationery / Stationery / Writing & Drawing / Colouring', None, 'South Africa', 'Staedtler Ballpoint Pens - Assorted Colours', None, '4,97265', 'Limited (6 months)', None, None, 36.0),
#  (None, None, None, '4007817432228', 223.0, 'Staedtler', 'Office & Stationery / Stationery / Writing & Drawing / Pens & Refills', None, 'South Africa', 'Staedtler Ballpoint Pens - Assorted Colours', None, '4,97265', 'Limited (6 months)', None, None, 36.0),
#  (None, None, None, '4007817432228', 223.0, 'Staedtler', 'Office & Stationery / Stationery / Student Supplies / Writing & Drawing / Pens & Refills', None, 'South Africa', 'Staedtler Ballpoint Pens - Assorted Colours', None, '4,97265', 'Limited (6 months)', None, None, 36.0),
#  (None, None, None, '4007817432228', 223.0, 'Staedtler', 'Office & Stationery / Stationery / Arts & Crafts / Drawing & Illustration', None, 'South Africa', 'Staedtler Ballpoint Pens - Assorted Colours', None, '4,97265', 'Limited (6 months)', None, None, 36.0),
#  ('1,05', '1,05', '4,45', '4008496635306', 235.0, 'Varta', 'Garden, Pool & Patio / Home Improvement / General Purpose Batteries', 'Blue', 'South Africa', 'Varta AAA Longlife Batteries - 6 Pack', None, 0.0, 'Limited (12 months)', None, '6 x AAA Battery', 59.0),
#  ('1,05', '1,05', '4,45', '4008496635306', 235.0, 'Varta', 'Camping & Outdoors / Coolers & Refrigeration / Mobile Refrigeration / Accessories / Battery Chargers & External Power', 'Blue', 'South Africa', 'Varta AAA Longlife Batteries - 6 Pack', None, 0.0, 'Limited (12 months)', None, '6 x AAA Battery', 59.0),
#  (None, None, None, '4015400264453', 256.0, 'Pampers', 'Baby & Toddler / Nappies & Changing / Nappies / Bedwetting Nappies', 'White', 'South Africa', 'PAMPERS NEW BABY-DRY SIZE 1 NEW BORN 27 PER PACK', None, '2,7298', 'Non-Returnable (6 months)', None, '27 Baby-Dry Nappies', 69.0),
#  (None, None, None, '4015400264453', 256.0, 'Pampers', 'Baby & Toddler / Nappies & Changing / Nappies / Disposable Nappies', 'White', 'South Africa', 'PAMPERS NEW BABY-DRY SIZE 1 NEW BORN 27 PER PACK', None, '2,7298', 'Non-Returnable (6 months)', None, '27 Baby-Dry Nappies', 69.0),
#  ('3,8', '23,6', '37,3', '4015400265016', 170.0, 'Pampers', 'Baby & Toddler / Nappies & Changing / Nappies / Bedwetting Nappies', 'White', 'South Africa', 'Pampers Baby Dry - Size 5 Mega Pack - 111 Nappies', None, 0.0, 'Non-Returnable (6 months)', None, '111 Baby-Dry Nappies', 449.0),
#  ('3,8', '23,6', '37,3', '4015400265016', 170.0, 'Pampers', 'Baby & Toddler / Nappies & Changing / Nappies / Disposable Nappies', 'White', 'South Africa', 'Pampers Baby Dry - Size 5 Mega Pack - 111 Nappies', None, 0.0, 'Non-Returnable (6 months)', None, '111 Baby-Dry Nappies', 449.0),
#  ('32,5', '25,6', '25,6', '4015400541813', 222.0, 'Pampers', 'Baby & Toddler / Nappies & Changing / Nappies / Disposable Nappies', 'White', 'South Africa', 'Pampers Premium Care - Size 5 Mega Pack - 88 Nappies', None, 0.0, 'Non-Returnable (6 months)', None, '88 Premium Care Nappies', 459.0),
#  (None, None, None, '4015400622079', 225.0, 'Pampers', 'Baby & Toddler / Nappies & Changing / Wipes', 'White', 'South Africa', 'Pampers Sensitive Baby Wipes - 4 x 56 - 224 Wipes', None, '4,21949', 'Non-Returnable (6 months)', None, '224 Sensitive Protect Wipes', 109.0),
#  (None, None, None, '4015400622727', 178.0, 'Pampers', 'Baby & Toddler / Nappies & Changing / Wipes', 'White', 'South Africa', 'Pampers Complete Clean Bulk Wipes - 12 x 64 - 768 Wipes - Bulk Pack', None, 0.0, 'Non-Returnable (6 months)', None, '768 Complete Clean Wipes', 319.0),
#  (None, None, None, '4015400636748', 429.0, 'Pampers', 'Baby & Toddler / Nappies & Changing / Wipes', 'White', 'South Africa', 'Pampers Sensitive Baby Wipes - 6 x 56 - 336 Wipes', None, '7,56217', 'Non-Returnable (6 months)', None, '336 Sensitive Protect Wipes', 159.0),
#  (None, None, None, '4015400687696', 116.0, 'Pampers', 'Baby & Toddler / Nappies & Changing / Nappies / Disposable Nappies', None, 'South Africa', 'Pampers Premium Care - Size 1 Carry Pack - 22 Nappies', None, 0.0, 'Non-Returnable (6 months)', None, '22 Premium Care Nappies', 49.0),
#  (None, None, None, '4210201043577', 419.0, 'Oral-B', 'Health / Personal Care / Oral Care / Toothbrushes / Electric Toothbrushes', None, 'South Africa', 'Oral-B Rechargeable Electric Toothbrush - Vitality Precision Clean', None, 0.0, 'Limited (24 months)', None, '1 x Rechargeable Toothbrush', 420.0),
#  (None, None, None, '4250947516027', 411.0, 'essence', 'Beauty / Makeup / Eyes / False Lashes', 'Black', 'South Africa', 'Essence Lash Princess False Lash Effect Mascara', None, 0.0, 'Non-Returnable', None, None, 69.0),
#  (None, None, None, '4260557510018', 383.0, 'Toshiba', 'Computers & Tablets / Drives & Storage / Portable HDD', 'Black', 'South Africa', "Toshiba Canvio Basic 1TB 2,5'' External Hard Drive", None, 0.0, 'Limited (24 months)', None, "1 X Toshiba Canvio Basic 1TB 2,5'' External Hard Drive", 830.0),
#  (None, None, None, '4547410173833', 2.0, 'Fujifilm Instax', 'Cameras / Cameras & Lenses / Camera Accessories / Instant Photo', None, 'South Africa', 'Fujifilm Instax Mini Film Plain Pack of 20', None, '11,81302', 'Limited (12 months)', None, None, 299.0),
#  (None, None, None, '4549292072389', 312.0, 'Canon', 'Computers & Tablets / Printers, Scanners & Copiers / Printers / Inkjet Printers', None, None, 'Canon PIXMA MG2540S A4 3in1 Multifunction Inkjet Printer', None, 0.0, 'Limited (12 months)', None, 'All-In-One printer \\96 Canon PIXMA MG2540S', 629.0),
#  (None, None, None, '4549292072389', 312.0, 'Canon', 'Computers & Tablets / Printers, Scanners & Copiers / Printers / Inkjet Printers', None, None, 'Canon PIXMA MG2540S A4 3in1 Multifunction Inkjet Printer', None, 0.0, 'Limited (12 months)', None, 'FINE Cartridges', 629.0),
#  (None, None, None, '4549292072389', 312.0, 'Canon', 'Computers & Tablets / Printers, Scanners & Copiers / Printers / Inkjet Printers', None, None, 'Canon PIXMA MG2540S A4 3in1 Multifunction Inkjet Printer', None, 0.0, 'Limited (12 months)', None, 'Power cord', 629.0),
#  (None, None, None, '4549292072389', 312.0, 'Canon', 'Computers & Tablets / Printers, Scanners & Copiers / Printers / Inkjet Printers', None, None, 'Canon PIXMA MG2540S A4 3in1 Multifunction Inkjet Printer', None, 0.0, 'Limited (12 months)', None, 'Setup CD-ROM (CD only for Windows \\96 Mac drivers available online)', 629.0),
#  (None, None, None, '4549292072389', 312.0, 'Canon', 'Office & Stationery / Office / Printers, Scanners & Copiers / Printers / Inkjet Printers', None, None, 'Canon PIXMA MG2540S A4 3in1 Multifunction Inkjet Printer', None, 0.0, 'Limited (12 months)', None, 'Manuals', 629.0),
#  (None, None, None, '4549292118766', 190.0, 'Canon', 'Computers & Tablets / Printers, Scanners & Copiers / Printers / Inkjet Printers', 'Black', 'South Africa', 'Canon PIXMA TR4540 A4 4-in-1 Wi-Fi Inkjet Printer', None, 0.0, 'Limited (12 months)', None, '4-in-one printer - PIXMA TR4540', 899.0),
#  (None, None, None, '4549292118766', 190.0, 'Canon', 'Computers & Tablets / Printers, Scanners & Copiers / Printers / Inkjet Printers', 'Black', 'South Africa', 'Canon PIXMA TR4540 A4 4-in-1 Wi-Fi Inkjet Printer', None, 0.0, 'Limited (12 months)', None, '2 FINE cartridges', 899.0),
#  (None, None, None, '4549292118766', 190.0, 'Canon', 'Computers & Tablets / Printers, Scanners & Copiers / Printers / Inkjet Printers', 'Black', 'South Africa', 'Canon PIXMA TR4540 A4 4-in-1 Wi-Fi Inkjet Printer', None, 0.0, 'Limited (12 months)', None, 'Power cord', 899.0),
#  (None, None, None, '4549292118766', 190.0, 'Canon', 'Computers & Tablets / Printers, Scanners & Copiers / Printers / Inkjet Printers', 'Black', 'South Africa', 'Canon PIXMA TR4540 A4 4-in-1 Wi-Fi Inkjet Printer', None, 0.0, 'Limited (12 months)', None, 'Set-up CD-ROM', 899.0),
#  (None, None, None, '4549292118766', 190.0, 'Canon', 'Office & Stationery / Office / Printers, Scanners & Copiers / Printers / Inkjet Printers', 'Black', 'South Africa', 'Canon PIXMA TR4540 A4 4-in-1 Wi-Fi Inkjet Printer', None, 0.0, 'Limited (12 months)', None, 'Manuals and other documents', 899.0),
#  (None, None, None, '4712366966727', 117.0, 'ADATA', 'Cellphones & Wearables / Wearables / Accessories / Charging Devices', 'Black', 'South Africa', 'Adata 20 000 Mah Power Bank - Black', None, '0,61288', 'Limited (12 months)', None, 'Adata 20 000 Mah Power Bank - Black , USB - Micro Cable', 449.0),
#  (None, None, None, '4712366966727', 117.0, 'ADATA', 'Cellphones & Wearables / Cellular Accessories / Batteries & Chargers / Power Banks', 'Black', 'South Africa', 'Adata 20 000 Mah Power Bank - Black', None, '0,61288', 'Limited (12 months)', None, 'Adata 20 000 Mah Power Bank - Black , USB - Micro Cable', 449.0),
#  (None, None, None, '4800361367493', 413.0, 'Nestle', 'Home & Kitchen / Household, Food & Beverages / Baby Food & Nutrition / Formula', None, 'South Africa', 'Nestle - Nan Optipro 3 - 1,8kg', None, 0.0, 'Limited (18 months)', '1,8', None, 325.0),
#  (None, None, None, '4800361367493', 413.0, 'Nestle', 'Baby & Toddler / Baby Food & Nutrition / Baby Formula', None, 'South Africa', 'Nestle - Nan Optipro 3 - 1,8kg', None, 0.0, 'Limited (18 months)', '1,8', None, 325.0),
#  (None, None, None, '4902505163104', 442.0, 'Pilot', 'Office & Stationery / Stationery / Office Supplies / Writing Tools / Fine Writing / Ballpoint Pens', None, 'South Africa', 'Pilot G-2 0,5 Fine Nib Gel Retractable Pen - Black', None, 0.0, 'Limited (6 months)', None, '1 Black Pen', 30.0),
#  (None, None, None, '4902505163104', 442.0, 'Pilot', 'Office & Stationery / Stationery / Office Supplies / Writing Tools / Pens & Refills / Gel Pens', None, 'South Africa', 'Pilot G-2 0,5 Fine Nib Gel Retractable Pen - Black', None, 0.0, 'Limited (6 months)', None, '1 Black Pen', 30.0),
#  (None, None, None, '4902505163104', 442.0, 'Pilot', 'Office & Stationery / Stationery / Office Supplies / Writing Tools / Pens & Refills / Rollerball Pens', None, 'South Africa', 'Pilot G-2 0,5 Fine Nib Gel Retractable Pen - Black', None, 0.0, 'Limited (6 months)', None, '1 Black Pen', 30.0),
#  (None, None, None, '4902505163104', 442.0, 'Pilot', 'Office & Stationery / Stationery / Writing & Drawing / Pens & Refills', None, 'South Africa', 'Pilot G-2 0,5 Fine Nib Gel Retractable Pen - Black', None, 0.0, 'Limited (6 months)', None, '1 Black Pen', 30.0),
#  (None, None, None, '4902505163104', 442.0, 'Pilot', 'Office & Stationery / Stationery / Student Supplies / Writing & Drawing / Pens & Refills', None, 'South Africa', 'Pilot G-2 0,5 Fine Nib Gel Retractable Pen - Black', None, 0.0, 'Limited (6 months)', None, '1 Black Pen', 30.0),
#  (None, None, None, '4902505163104', 442.0, 'Pilot', 'Office & Stationery / Stationery / Arts & Crafts / Drawing & Illustration', None, 'South Africa', 'Pilot G-2 0,5 Fine Nib Gel Retractable Pen - Black', None, 0.0, 'Limited (6 months)', None, '1 Black Pen', 30.0),
#  (None, None, None, '4902505163166', 261.0, None, 'Office & Stationery / Stationery / Office Supplies / Writing Tools / Fine Writing / Mechanical Pens', None, 'South Africa', 'Pilot G-2 0,7 Gel Retractable Pen - Black', None, 0.0, None, None, '1 Black Pen', 32.0),
#  (None, None, None, '4902505163166', 261.0, None, 'Office & Stationery / Stationery / Office Supplies / Writing Tools / Fine Writing / Ballpoint Pens', None, 'South Africa', 'Pilot G-2 0,7 Gel Retractable Pen - Black', None, 0.0, None, None, '1 Black Pen', 32.0),
#  (None, None, None, '4902505163166', 261.0, None, 'Office & Stationery / Stationery / Office Supplies / Writing Tools / Pens & Refills / Gel Pens', None, 'South Africa', 'Pilot G-2 0,7 Gel Retractable Pen - Black', None, 0.0, None, None, '1 Black Pen', 32.0),
#  (None, None, None, '4902505163166', 261.0, None, 'Office & Stationery / Stationery / Office Supplies / Writing Tools / Pens & Refills / Rollerball Pens', None, 'South Africa', 'Pilot G-2 0,7 Gel Retractable Pen - Black', None, 0.0, None, None, '1 Black Pen', 32.0),
#  (None, None, None, '4902505163166', 261.0, None, 'Office & Stationery / Stationery / Writing & Drawing / Pens & Refills', None, 'South Africa', 'Pilot G-2 0,7 Gel Retractable Pen - Black', None, 0.0, None, None, '1 Black Pen', 32.0),
# ...
#  (None, None, None, 'MPTAL00284134', 308.0, None, 'TV, Audio & Video / Audio / Home Audio / Turntable Cartridges & Needles', None, None, 'Earbud Earphones H5 - White', None, 0.0, 'Limited (6 months)', None, '1 x Earbud Earphones H5 - White', 119.0),
#  (None, None, None, 'MPTAL00345127', 125.0, 'Dumar Trading Co', 'Toys / Indoor Play / Baby & Toddler / Shape Sorters', None, None, 'Educational Baby Game with Shapes and Beginner Clock', None, 0.0, 'Limited (6 months)', None, None, 170.0),
#  (None, None, None, 'MPTAL00345127', 125.0, 'Dumar Trading Co', 'Toys / Indoor Play / Educational Toys (STEM) / Mathematics', None, None, 'Educational Baby Game with Shapes and Beginner Clock', None, 0.0, 'Limited (6 months)', None, None, 170.0),
#  ('13,4', '14,8', '13,2', 'MPTAL00348001', 317.0, None, 'Baby & Toddler / Baby Room / Decor / Night Lights', 'Blue', 'South Africa', 'Star Master Night Light - Blue', None, 0.0, 'Limited (6 months)', None, '1 x Night Light', 119.0),
#  (0.0, 0.0, 0.0, 'MPTAL00348002', 215.0, None, 'Toys / Kids Decor / Kids Room Decor', 'Pink', 'South Africa', 'Star Master Night Light - Pink', None, '3,6104', 'Limited (6 months)', None, 'STAR MASTER', 119.0),
#  (None, None, None, 'MPTAL00351637', 471.0, 'Mix Box', 'Gaming / Gaming Accessories / Gaming Mouse Pads', None, None, 'Mix Box Large XL Size Anti-Slip World Map Speed Game Mouse Pad Gaming Mat for Laptop PC', None, 0.0, 'Limited (6 months)', None, '1 x mousepad', 149.0),
#  (None, None, None, 'MPTAL00351754', 49.0, 'LASA', 'Home & Kitchen / Homeware / Kitchen / Kitchen Organisation & Utensils / Kitchen Utensils / Timers & Thermometers', None, None, 'Digital Stainless Cooking Thermometer', None, '0,36989', 'Limited (6 months)', None, '1x cooking thermometer', 157.0),
#  (None, None, None, 'MPTAL00363106', 279.0, 'Torch SA', 'Camping & Outdoors / Lighting / Torches', None, None, 'Police Type Self-Defensive LED Torch + Stun Gun', None, '0,65856', 'Limited (6 months)', None, 'LED Flashlight, 1 Home Charger, 1 Lithium Battery', 97.0),
#  (None, None, None, 'MPTAL00376613', 156.0, None, 'Garden, Pool & Patio / Patio / Patio Furniture / Patio Tables', None, None, 'Minhaj - 1,8m Folding Trestle Table', None, '16,00113', 'Limited (6 months)', None, '1 x Folding Table', 729.0),
#  (None, None, None, 'MPTAL00403440', 431.0, 'Mix Box', 'Cellphones & Wearables / Cellular Accessories / Mounts & Stands', None, None, 'Mix Box Metal Cell Phone Stand', None, 0.0, 'Limited (6 months)', None, None, 129.0),
#  (None, None, None, 'MPTAL00403443', 493.0, 'Mix Box', 'Pets / Equipment & Accessories / Containment', None, None, 'Mix Box Pet Car Seat Cover', None, 0.0, 'Limited (6 months)', None, None, 349.0),
#  (None, None, None, 'MPTAL00404508', 127.0, 'Securi-Prod', 'Garden, Pool & Patio / DIY Tools & Machinery / Power Tools & Machinery / Power Tool Parts & Accessories / Batteries & Chargers', None, None, 'Securi-Prod Battery 12V 7AH', None, 0.0, 'Limited (6 months)', None, None, 256.0),
#  (None, None, None, 'MPTAL00404857', 410.0, None, 'TV, Audio & Video / TV & Audio Accessories / Cables', None, None, 'HDMI 5m Braided Cable', None, 0.0, 'Limited (6 months)', None, '1X 5M BRAIDED CABLE', 78.0),
#  (None, None, None, 'MPTAL00404858', 216.0, 'Stonebaby', 'TV, Audio & Video / TV & Audio Accessories / Cables', None, None, 'HDMI 10m Braided Cable', None, '1,61032', 'Limited (6 months)', None, '1X 10M BRAIDED HDMI CABLE', 87.0),
#  (None, None, None, 'MPTAL00410764', 244.0, 'LDNIO', 'Cellphones & Wearables / Cellular Accessories / Cellphone Cables', 'White', None, 'USB Type C Data Cable - White', None, 0.0, 'Limited (6 months)', None, '1 x USB-C to USB-A cable', 45.0),
#  (None, None, None, 'MPTAL00424197', 100.0, None, 'Fashion / Clothing / Underwear / Shapewear', None, None, 'Adjustable Hook & Loop Waist Trainer Belt - Black', None, 0.0, 'Limited (6 months)', None, '1 x Waist Training Belt', 219.0),
#  (7.0, 13.0, 3.0, 'MPTAL00434245', 492.0, None, 'Cameras / Cameras & Lenses / Camera Accessories / Tripods & Stands / Tripod Kits', 'Black', None, 'Spider Flexible Camera Tripod - Black', None, 0.0, 'Limited (6 months)', None, '1 x Camera', 92.0),
#  (None, None, None, 'MPTAL0043424593', 319.0, 'Steel Mate', 'Health / Health Care / First Aid / First Aid Supplies / Gloves & Masks', 'Black', None, 'Sports Face Mask with Exhalation Valves', None, 0.0, 'Limited (6 months)', None, '1 x Sports Face Mask', 83.0),
#  (None, None, None, 'MPTAL0043424593', 319.0, 'Steel Mate', 'Health / Health Care / First Aid / First Aid Supplies / Gloves & Masks', 'Black', None, 'Sports Face Mask with Exhalation Valves', None, 0.0, 'Limited (6 months)', None, '1 x Pre-installed filter', 83.0),
#  (None, None, None, 'MPTAL0043424594', 456.0, None, 'Health / Health Care / First Aid / First Aid Supplies / Gloves & Masks', None, None, 'Face Mask - Kids Pink Reusable Sponge with Panda Valve', None, 0.0, 'Limited (6 months)', None, '1 x Sponge mask with panda valve', 52.0),
#  (None, None, None, 'MPTAL00440824', 386.0, None, 'Gaming / Gaming Accessories / Controllers', 'Black', None, 'Wireless Double Shock Controller for PS3', None, 0.0, 'Limited (6 months)', None, '1x PS3 Wireless Double Stock Controller', 187.0),
#  ('13,6', '8,8', '2,6', 'MPTAL00444041', 488.0, None, 'Cellphones & Wearables / Wearables / Activity Trackers', 'Black', None, 'Smart M2 Fitness Watch - Black', None, 0.0, 'Limited (6 months)', None, None, 238.0),
#  (None, None, None, 'MPTAL00451356', 319.0, 'Berlinger Haus', 'Home & Kitchen / Homeware / Dining Room / Cutlery / Knives', None, None, 'Berlinger Haus 6 Piece Marble Coated Knife Set', None, 0.0, 'Limited (6 months)', None, '1 x Chef knife 20 cm', 329.0),
#  (None, None, None, 'MPTAL00451356', 319.0, 'Berlinger Haus', 'Home & Kitchen / Homeware / Dining Room / Cutlery / Knives', None, None, 'Berlinger Haus 6 Piece Marble Coated Knife Set', None, 0.0, 'Limited (6 months)', None, '1 x Bread knife 20 cm', 329.0),
#  (None, None, None, 'MPTAL00451356', 319.0, 'Berlinger Haus', 'Home & Kitchen / Homeware / Dining Room / Cutlery / Knives', None, None, 'Berlinger Haus 6 Piece Marble Coated Knife Set', None, 0.0, 'Limited (6 months)', None, '1 x Santoku knife 17,5 cm', 329.0),
#  (None, None, None, 'MPTAL00451356', 319.0, 'Berlinger Haus', 'Home & Kitchen / Homeware / Dining Room / Cutlery / Knives', None, None, 'Berlinger Haus 6 Piece Marble Coated Knife Set', None, 0.0, 'Limited (6 months)', None, '1 x Utility knife 12,5 cm', 329.0),
#  (None, None, None, 'MPTAL00451356', 319.0, 'Berlinger Haus', 'Home & Kitchen / Homeware / Dining Room / Cutlery / Knives', None, None, 'Berlinger Haus 6 Piece Marble Coated Knife Set', None, 0.0, 'Limited (6 months)', None, '1 x Paring knife 9 cm', 329.0),
#  (None, None, None, 'MPTAL00451356', 319.0, 'Berlinger Haus', 'Home & Kitchen / Homeware / Dining Room / Cutlery / Knives', None, None, 'Berlinger Haus 6 Piece Marble Coated Knife Set', None, 0.0, 'Limited (6 months)', None, '1 x Santoku knife 9 cm', 329.0),
#  (None, None, None, 'MPTAL00451356', 319.0, 'Berlinger Haus', 'Home & Kitchen / Homeware / Kitchen / Kitchen Scissors & Knives / Knives', None, None, 'Berlinger Haus 6 Piece Marble Coated Knife Set', None, 0.0, 'Limited (6 months)', None, '1 x Chef knife 20 cm', 329.0),
#  (None, None, None, 'MPTAL00451356', 319.0, 'Berlinger Haus', 'Home & Kitchen / Homeware / Kitchen / Kitchen Scissors & Knives / Knives', None, None, 'Berlinger Haus 6 Piece Marble Coated Knife Set', None, 0.0, 'Limited (6 months)', None, '1 x Bread knife 20 cm', 329.0),
#  (None, None, None, 'MPTAL00451356', 319.0, 'Berlinger Haus', 'Home & Kitchen / Homeware / Kitchen / Kitchen Scissors & Knives / Knives', None, None, 'Berlinger Haus 6 Piece Marble Coated Knife Set', None, 0.0, 'Limited (6 months)', None, '1 x Santoku knife 17,5 cm', 329.0),
#  (None, None, None, 'MPTAL00451356', 319.0, 'Berlinger Haus', 'Home & Kitchen / Homeware / Kitchen / Kitchen Scissors & Knives / Knives', None, None, 'Berlinger Haus 6 Piece Marble Coated Knife Set', None, 0.0, 'Limited (6 months)', None, '1 x Utility knife 12,5 cm', 329.0),
#  (None, None, None, 'MPTAL00451356', 319.0, 'Berlinger Haus', 'Home & Kitchen / Homeware / Kitchen / Kitchen Scissors & Knives / Knives', None, None, 'Berlinger Haus 6 Piece Marble Coated Knife Set', None, 0.0, 'Limited (6 months)', None, '1 x Paring knife 9 cm', 329.0),
#  (None, None, None, 'MPTAL00451356', 319.0, 'Berlinger Haus', 'Home & Kitchen / Homeware / Kitchen / Kitchen Scissors & Knives / Knives', None, None, 'Berlinger Haus 6 Piece Marble Coated Knife Set', None, 0.0, 'Limited (6 months)', None, '1 x Santoku knife 9 cm', 329.0),
#  (None, None, None, 'MPTAL00490334', 264.0, None, 'Cellphones & Wearables / Cellular Accessories / Cellphone Cables', None, None, 'Lightning to Headphone Jack Adapter for iPhone', None, 0.0, 'Limited (6 months)', None, '1 x Jack Adapter', 52.0),
#  (None, None, None, 'MPTAL00490467', 139.0, 'Bootlegger', 'Home & Kitchen / Small Kitchen Appliances / Coffee & Tea / Coffee & Tea Supplies / Capsules', None, None, 'Bootlegger Coffee Capsule Sleeve - 10 Capsules', None, 0.0, 'Limited (6 months)', None, '1 sleeve containing 10 individual capsules filled with Bootlegger 100% Arabica coffee', 75.0),
#  (None, None, None, 'MPTAL00490945', 411.0, 'Sonoff', 'Computers & Tablets / Smart Home & Connected Living', None, None, 'Sonoff Basic Smart Switch', None, 0.0, 'Limited (6 months)', None, '1x 10 Amp Wifi Switch', 204.0),
#  (None, None, None, 'MPTAL00490945', 411.0, 'Sonoff', 'Computers & Tablets / Smart Home & Connected Living', None, None, 'Sonoff Basic Smart Switch', None, 0.0, 'Limited (6 months)', None, '4x Screws', 204.0),
#  (None, None, None, 'MPTAL00490945', 411.0, 'Sonoff', 'Computers & Tablets / Smart Home & Connected Living', None, None, 'Sonoff Basic Smart Switch', None, 0.0, 'Limited (6 months)', None, '1x Manual', 204.0),
#  (None, None, None, 'MPTAL00499706', 497.0, None, 'Health / Health Care / Health Supplies & Equipment / Health Equipment / Oximeters', None, None, 'Medmart Health Fingertip Pulse Oximeter', None, 0.0, 'Limited (6 months)', None, None, 179.0),
#  (None, None, None, 'MPTAL00502446', 469.0, None, 'Computers & Tablets / Accessories / Cable Adapters', None, None, 'USB 2,0 A to B 1,5m HP, Canon & Lexmark Printer Cable', None, 0.0, 'Limited (6 months)', None, None, 76.0),
#  (None, None, None, 'MPTAL00511062', 409.0, None, 'Gaming / Gaming Accessories / Controllers', None, None, 'Charging Station PS4 Playstation Dual Shock Controller', None, 0.0, 'Limited (6 months)', None, '1 x Charging Station PS4 Playstation Dual Shock Controller', 164.0),
#  (None, None, None, 'MPTAL00512782', 298.0, None, 'Computers & Tablets / Accessories / Cables / Display Cables\r\nComputers & Tablets / Accessories / Cable Adapters', None, None, 'HDMi Cable Braided 3m - Black & Red', None, 0.0, 'Limited (6 months)', None, '1X 3M HDMI CABLE', 68.0),
#  (None, None, None, 'MPTAL00528272', 449.0, 'LASA', 'Home & Kitchen / Homeware / Kitchen / Food Preparation / Kitchen Scales', 'Bronze', None, 'Lasa 500g/0,01g Digital Pocket Scale', None, 0.0, 'Limited (6 months)', None, 'Lasa 500g/0,01g Digital Pocket Scale', 220.0),
#  (None, None, None, 'MPTAL00528272', 449.0, 'LASA', 'Home & Kitchen / Homeware / Kitchen / Bakeware / Kitchen Scales', 'Bronze', None, 'Lasa 500g/0,01g Digital Pocket Scale', None, 0.0, 'Limited (6 months)', None, 'Lasa 500g/0,01g Digital Pocket Scale', 220.0),
#  (None, None, None, 'MPTAL00531596', 439.0, 'Generic', 'Computers & Tablets / Accessories / Cable Adapters', None, None, 'Wifi Extender / Repeater - up to 300mbps', None, 0.0, 'Limited (6 months)', None, '1 x Wireless Wifi Extender Repeater (US Plug)', 279.0),
#  (None, None, None, 'MPTAL00531596', 439.0, 'Generic', 'Computers & Tablets / Accessories / Cable Adapters', None, None, 'Wifi Extender / Repeater - up to 300mbps', None, 0.0, 'Limited (6 months)', None, '1 x RJ-45 Networking Cable', 279.0),
#  (None, None, None, 'MPTAL00531596', 439.0, 'Generic', 'Computers & Tablets / Accessories / Cable Adapters', None, None, 'Wifi Extender / Repeater - up to 300mbps', None, 0.0, 'Limited (6 months)', None, ' x Installation Manual', 279.0),
#  (None, None, None, 'MPTAL00531596', 439.0, 'Generic', 'Computers & Tablets / Networking / Extenders & Repeaters', None, None, 'Wifi Extender / Repeater - up to 300mbps', None, 0.0, 'Limited (6 months)', None, '1 x Wireless Wifi Extender Repeater (US Plug)', 279.0),
#  (None, None, None, 'MPTAL00531596', 439.0, 'Generic', 'Computers & Tablets / Networking / Extenders & Repeaters', None, None, 'Wifi Extender / Repeater - up to 300mbps', None, 0.0, 'Limited (6 months)', None, '1 x RJ-45 Networking Cable', 279.0),
#  (None, None, None, 'MPTAL00531596', 439.0, 'Generic', 'Computers & Tablets / Networking / Extenders & Repeaters', None, None, 'Wifi Extender / Repeater - up to 300mbps', None, 0.0, 'Limited (6 months)', None, '1 x Installation Manual', 279.0),
#  (None, None, None, 'MPTAL00531596', 439.0, 'Generic', 'Computers & Tablets / Networking / Access Points & Routers', None, None, 'Wifi Extender / Repeater - up to 300mbps', None, 0.0, 'Limited (6 months)', None, '1 x Wireless Wifi Extender Repeater (US Plug)', 279.0),
#  (None, None, None, 'MPTAL00531596', 439.0, 'Generic', 'Computers & Tablets / Networking / Access Points & Routers', None, None, 'Wifi Extender / Repeater - up to 300mbps', None, 0.0, 'Limited (6 months)', None, '1 x RJ-45 Networking Cable', 279.0),
#  (None, None, None, 'MPTAL00531596', 439.0, 'Generic', 'Computers & Tablets / Networking / Access Points & Routers', None, None, 'Wifi Extender / Repeater - up to 300mbps', None, 0.0, 'Limited (6 months)', None, '1 x Installation Manual', 279.0),
#  (None, None, None, 'MPTAL00532468', 398.0, None, 'Cellphones & Wearables / Wearables / Accessories / Charging Devices', None, None, 'Adaptive Fast Charger Micro USB Cable for Smartphones', None, 0.0, 'Limited (6 months)', None, '1 x Micro USB Cable', 74.0),
#  (None, None, None, 'MPTAL00532468', 398.0, None, 'Cellphones & Wearables / Cellular Accessories / Batteries & Chargers / Cellphone Chargers', None, None, 'Adaptive Fast Charger Micro USB Cable for Smartphones', None, 0.0, 'Limited (6 months)', None, '1 x Micro USB Cable', 74.0),
#  (None, None, None, 'MPTAL00533857', 335.0, 'LDNIO', 'Cellphones & Wearables / Wearables / Accessories / Charging Devices', None, None, 'LDNIO Dual USB Travel Wall Charger Power Adapter (A2202)', None, 0.0, 'Limited (6 months)', None, '1x dual wall charger', 89.0),
#  (None, None, None, 'MPTAL00533857', 335.0, 'LDNIO', 'Cellphones & Wearables / Cellular Accessories / Batteries & Chargers / Cellphone Chargers', None, None, 'LDNIO Dual USB Travel Wall Charger Power Adapter (A2202)', None, 0.0, 'Limited (6 months)', None, '1x dual wall charger', 89.0),
#  (None, None, None, 'MPTAL00538061', 366.0, None, 'Cellphones & Wearables / Cellular Accessories / Cellphone Cables', None, None, 'Charging Cable for Iphone 6 /7 /7 Plus/8 & 8 Plus', None, 0.0, 'Limited (6 months)', None, 'Charging Cable for Iphone 6 /7 /7 Plus/8 & 8 Plus', 49.0),
#  (None, None, None, 'MPTAL00541865', 288.0, '&Accessories', 'Home & Kitchen / Homeware / Kitchen / Kitchen Organisation & Utensils / Kitchen Utensils / Timers & Thermometers', 'Blue', None, 'Digital Temperature & Humidity Thermometer Indoor Clock', None, 0.0, 'Limited (6 months)', None, 'Digital Temperature & Humidity Thermometer Indoor Clock', 129.0),
#  (None, None, None, 'MPTAL00555756', 194.0, None, 'Sport / Fitness / Fitness Accessories / Other Fitness Accessories', 'Assorted', None, 'Sparq Active Resistance Loop Band - Set of 5 with Bag', None, 0.0, 'Limited (6 months)', None, '5 x resistance bands', 199.0),
#  (None, None, None, 'MPTAL00555756', 194.0, None, 'Sport / Fitness / Fitness Accessories / Other Fitness Accessories', 'Assorted', None, 'Sparq Active Resistance Loop Band - Set of 5 with Bag', None, 0.0, 'Limited (6 months)', None, '1 x carry case', 199.0),
#  ...]

# %% [markdown]
# Q2) How many users bought from Bhejane in April 2020?

# %%
# %%sql
# SELECT UserName
# FROM Transactions
# WHERE InvoiceDate = '2020-03-25'
# Out:
#  * sqlite:///bhejane.db
# Done.
# []

# %% [markdown]
# Q3) How many users bought 3 or more items that cost more than R1000?

# %%
# %%sql
# SELECT DISTINCT InvoiceDate
# FROM Transactions
# WHERE UserName = 'Mandla';
# Out:
#  * sqlite:///bhejane.db
# Done.
# [('2020-06-07 0:00:00',), ('2020-04-09 0:00:00',), ('2020-04-11 0:00:00',)]

# %% [markdown]
# Q4) Which user made the largest purchase on a single transaction?

# %%
# %%sql
# SELECT Brand, COUNT(DISTINCT ProductDescription) AS Variety
# FROM Products
# GROUP BY Brand
# ORDER BY Variety DESC
# LIMIT 5;
# Out:
#  * sqlite:///bhejane.db
# Done.
# [(None, 180),
#  ('SanDisk', 16),
#  ('Pampers', 11),
#  ('Russell Hobbs', 10),
#  ('Canon', 9)]

# %% [markdown]
# Q5) How many components does the product: "5m Colour Changing RGB LED Strip Light" (MPTAL57588104) come with?

# %%
# %%sql
# SELECT Total
# FROM Transactions
# WHERE UserName = 'Zanele' AND InvoiceDate = '2020-04-04';
# Out:
#  * sqlite:///bhejane.db
# Done.
# []

# %% [markdown]
# Q6) How many brands are available at Bhejane?

# %%
# %%sql
# SELECT UserName, SUM(Total) AS TotalSpent
# FROM Transactions
# WHERE InvoiceDate >= '2020-01-01' AND InvoiceDate <= '2020-12-31'
# GROUP BY UserName
# HAVING COUNT(*) = 4
# ORDER BY TotalSpent DESC
# LIMIT 1;
# Out:
#  * sqlite:///bhejane.db
# Done.
# [('keith', 2980.0)]

# %% [markdown]
# 7) What is the price of the "Verimark - Floorwiz 2in1 Mop"?

# %%
# %%sql
# SELECT SUM(Transactions.Total) AS TotalPrice
# FROM Transactions
# JOIN Products ON Transactions.Barcode = Products.Barcode
# WHERE Products.NavigationPath IN ('Estee Lauder Double Wear Stay In Place Makeup', 'Angelcare - Nappy Bin Refill - 3 Pack', 'RCT 650VA Line Interactive UPS')
# Out:
#  * sqlite:///bhejane.db
# Done.
# [(None,)]

# %% [markdown]
# Q8) Calculate the package volume of the "Russell Hobbs - Slow Cooker" using the given dimensions

# %%
# %%sql
# SELECT ProductDescription, Quantity
# FROM Products
# ORDER BY Quantity DESC
# LIMIT 1;
# Out:
#  * sqlite:///bhejane.db
# Done.
# [('Beard Growth Essential Oil', 500.0)]

# %% [markdown]
# Q9) Which user made the most transactions in the Year 2020?

# %%
# %%sql
# SELECT COUNT(*) AS NumProducts
# FROM Products
# WHERE StockCountry = 'United Kingdom';
# Out:
#  * sqlite:///bhejane.db
# Done.
# [(8,)]

# %% [markdown]
# Q10) What is the total number of users that shop at Bhejane?

# %%
# %%sql
# SELECT ProductDescription, Colour
# FROM Products
# WHERE Barcode = 'TAL00035388021';
# Out:
#  * sqlite:///bhejane.db
# Done.
# [('Angelcare - Nappy Bin Refill - 3 Pack', 'Blue'),
#  ('Angelcare - Nappy Bin Refill - 3 Pack', 'Blue'),
#  ('Angelcare - Nappy Bin Refill - 3 Pack', 'Blue'),
#  ('Angelcare - Nappy Bin Refill - 3 Pack', 'Blue')]

# %% [markdown]
# Q11) What is the record count for the Colours_3NF Table?

# %%
# %%sql
# SELECT COUNT(DISTINCT Brand) AS BeerBrandCount
# FROM products
# WHERE Brand IN (
#     'Three Ships', 'Wellington', 'Richelieu', 'Klipdrift', 'Metalix',
#     'Castle Lite', 'Castle Free', 'Heineken'
#
# );
# Out:
#  * sqlite:///bhejane.db
# Done.
# [(8,)]

# %% [markdown]
# Q12) What would the total price be if I had the following items in my cart?
# * MPTAL57588104
# * 5000394203921
# * 6932391917652

# %%
# %%sql
# SELECT ProductDescription, COUNT(DISTINCT NavigationPath) AS PathCount, Quantity
# FROM Products
# GROUP BY ProductDescription, Quantity
# HAVING PathCount > 2
# ORDER BY Quantity DESC
# LIMIT 10;
# Out:
#  * sqlite:///bhejane.db
# Done.
# [('Croxley Create Fine Nib Whiteboard Markers - Blister of 10', 11, 482.0),
#  ('Addis - Window Squeegee Long Handle', 3, 474.0),
#  ("Butterfly Filing Pockets A4 100's", 5, 471.0),
#  ('Art Set - 66 Piece', 4, 468.0),
#  ('Pilot G-2 0,5 Fine Nib Gel Retractable Pen - Black', 6, 442.0),
#  ('Wifi Extender / Repeater - up to 300mbps', 3, 439.0),
#  ('Pritt Stick 43g Glue Stick', 6, 431.0),
#  ('100% Cotton 3-ply Face Mask - Navy', 3, 422.0),
#  ('SanDisk 64GB 98 MB/s Ultra Micro UHS-l SDXC C10', 3, 419.0),
#  ('Energizer CR2032 Lithium Coin Battery - 3V', 3, 418.0)]

# %% [markdown]
# Q13) What is the barcode of the most sold product?

# %%
# %%sql
# SELECT Transactions.UserName, Products.Warranty
# FROM Transactions
# JOIN Products ON Transactions.Barcode = Products.Barcode
# WHERE Products.ProductDescription = 'Canon PG-445 & CL-446 Ink Cartridges Multipack'
#   AND strftime('%Y-%m', Transactions.InvoiceDate) = '2020-05'
# LIMIT 1;
# Out:
#  * sqlite:///bhejane.db
# Done.
# []

# %% [markdown]
# Q14) What are the products of Cornelis’ cart on the 2020-06-28 0:00:00?

# %%
# %%sql
# SELECT DISTINCT Transactions.UserName
# FROM Transactions
# JOIN Products ON Transactions.Barcode = Products.Barcode
# WHERE Products.Brand = 'Russell Hobbs'
#   AND Products.Colour = 'Silver';
# Out:
#  * sqlite:///bhejane.db
# Done.
# [('Karyn',), ('Clodeane',)]

# %% [markdown]
# Q15) Which users bought locally produced, black-coloured products on odd-numbered months of the year, and what was the total cost (rounded to the nearest integer) of the carts containing these products?

# %%
# %%sql
#
# SELECT SUM(Price) AS TotalPrice
# FROM Products
# WHERE ProductDescription IN ('Estee Lauder Double Wear Stay In Place Makeup', 'Angelcare - Nappy Bin Refill - 3 Pack', 'RCT 650VA Line Interactive UPS');
# Out:
#  * sqlite:///bhejane.db
# Done.
# [(6356.0,)]
